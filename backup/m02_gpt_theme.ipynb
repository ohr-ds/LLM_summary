# %% [markdown]
# # 패키지 불러오기

# %%
# !openai --version
# Out:
# openai 1.35.7

# %%
import os
import yaml
import json

from openai import OpenAI
import pandas as pd
import numpy as np
import ipywidgets as widgets # interactive display
from tqdm import tqdm # progress bar
from dotenv import load_dotenv
from collections import defaultdict

# %% [markdown]
# # ENV, Config 파일 읽기

# %%
# .env 파일에서 환경 변수 로드(API 키)
load_dotenv()
# Out:
# True

# %%
# YAML 파일 열기
yaml_path = 'config.yaml' # todo: config 파일과 합치기

with open(yaml_path, 'r') as f:
    config = yaml.safe_load(f)

# gpt prompt 설정
sentiment_instructions = config['gptapi']['sentiment']['instructions']
sentiment_few_shots = config['gptapi']['sentiment']['few_shot_examples']
theme_instructions = config['gptapi']['theme']['instructions']
theme_few_shots = config['gptapi']['theme']['few_shot_examples']

# %% [markdown]
# # 인스턴스 생성

# %%
# OpenAI API 클라이언트 생성
client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))

# %% [markdown]
# # 함수 정의

# %%
def get_response(messages):
    """
    model: 모델 종류
    messages: 사용자의 입력과 모델의 출력을 교환하는 메시지 목록
    max_tokens: 생성될 응답의 최대 길이
    temperature: 생성될 응답의 다양성(0.0 ~ 1.0) 0.0은 가장 확실한 답변을, 1.0은 가장 다양한 답변을 생성
    stream: 응답을 한 번에 반환할지 여부. False로 설정하면 한 번에 반환
    """
    try:
        response = client.chat.completions.create(
            model = "gpt-4o",
            messages = messages,
            # max_tokens = 150,
            temperature = 0.5,
            stream = False)
        return response.choices[0].message.content
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# JSON 응답에서 raw_text 항목을 추출하는 함수
def extract_raw_text(content):
    return content.get('raw_text', '')

# JSON 응답에서 issue 항목을 추출하는 함수
def extract_issues(content):
    return content.get('issue', [])

# JSON 응답에서 각 issue에 대한 sentiment 값을 추출하는 함수
def extract_sentiments(content):
    return content.get('sentiment', {})

# JSON 응답에서 sentiment_all 값을 추출하는 함수
def extract_sentiment_all(content):
    return content.get('sentiment_all', '')

# 문자열을 딕셔너리로 변환하는 함수
def convert_to_dict(content):
    try:
        return json.loads(content)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        return None
    
# JSON 데이터를 변환하고 추출된 데이터를 DataFrame으로 변환하는 함수
def convert_to_dataframe(content_list):
    data = []
    
    for content in content_list:
        if not content:
            continue  # content가 None이거나 비어 있을 때 건너뜀
        
        content_dict = convert_to_dict(content)
        if not content_dict:
            continue  # JSON 변환에 실패한 경우 건너뜀
        
        raw_text = extract_raw_text(content_dict)
        issues = extract_issues(content_dict)
        sentiments = extract_sentiments(content_dict)
        sentiment_all = extract_sentiment_all(content_dict)
        
        # 각 issue와 sentiment를 별도로 저장
        for issue, sentiment in sentiments.items():
            data.append({
                "raw_text": raw_text,
                "issue": issue,
                "sentiment": sentiment,
                "sentiment_all": sentiment_all
            })
    
    # 데이터가 있을 경우에만 DataFrame 생성
    if data:
        return pd.DataFrame(data)
    else:
        print("No valid data to create DataFrame.")
        return pd.DataFrame()  # 빈 DataFrame 반환
    
def map_issues_to_themes(issues_list, clustering_response):
    themes = []
    for issues in issues_list:
        issue_themes = set()  # 중복을 방지하기 위해 set 사용
        for issue in issues:
            for theme, issue_group in clustering_response.items():
                if issue in issue_group:
                    issue_themes.add(theme)
        themes.append(", ".join(issue_themes))  # 여러 테마가 있을 경우 ","로 결합
    return themes

# 후처리 함수 정의(리스트, 딕셔너리 형태를 문자열로 변환)
def clean_format(value):
    if isinstance(value, list):
        return ', '.join(value)  # 리스트의 경우 ,로 구분하여 문자열로 변환
    if isinstance(value, dict):
        return ', '.join([f"{k}: {v}" for k, v in value.items()])  # 딕셔너리의 경우 key: value 형식으로 변환
    return value  # 이미 문자열인 경우는 그대로 반환

# %%
def classify_issues(issues):
    # 'instructions'는 모델의 행동 방침을 설정하므로 system 메시지에 포함
    messages = [
        {"role": "system", "content": theme_instructions},
        {"role": "user", "content": f"다음 이슈들을 의미적으로 비슷한 그룹으로 나누고, 각 그룹의 공통 테마를 도출해줘: {issues}"},
        {"role": "user", "content": f"예시: {theme_few_shots}"}
    ]
    
    return get_response(messages)

# themes 리스트의 각 JSON 문자열을 dict 형태로 변환하여 병합하는 함수
def merge_themes(themes):
    merged_dict = defaultdict(list)  # 리스트를 기본값으로 갖는 defaultdict 생성

    for theme in themes:
        # JSON 문자열을 Python dict로 변환
        theme_dict = json.loads(theme)
        
        # 각 key와 value를 병합
        for key, values in theme_dict.items():
            for value in values:
                if value not in merged_dict[key]:  # 중복된 value가 없을 경우만 추가
                    merged_dict[key].append(value)
    
    return dict(merged_dict)  # defaultdict을 일반 dict로 변환하여 반환

# 'theme' 컬럼을 생성하는 함수(이슈를 테마로 매핑)
def find_theme(merged_themes, issue):
    for theme, issues in merged_themes.items():
        if issue in issues:
            return theme
    return '기타'  # 해당하는 theme이 없을 경우 '기타'로 표시

# %% [markdown]
# # 파일 읽기

# %%
result = pd.read_pickle('result/제공_네이버쇼핑리뷰_S1_감성분석.pkl')

# %%
result
# Out:
#                                                raw_text       issue sentiment  \
# 0                                        조아용 조아용 조아용 ㅎㅎ       좋은 제품        긍정
# 1                                        너무 만족하며 사용중입니다          만족        긍정
# 2         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요    빠른 설치 배송        긍정
# 3         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요   설치 서비스 만족        긍정
# 4                          여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요     여자친구 만족        긍정
# ...                                                 ...         ...       ...
# 2468  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...    야외 사용 기대        긍정
# 2469  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...        대대만족        긍정
# 2470  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...  아늑한 영화관 느낌        긍정
# 2471  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...       이동 편리        긍정
# 2472  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...     캠핑에서 유용        긍정
#
#      sentiment_all
# 0               긍정
# 1               긍정
# 2               긍정
# 3               긍정
# 4               긍정
# ...            ...
# 2468            긍정
# 2469            긍정
# 2470            긍정
# 2471            긍정
# 2472            긍정
#
# [2473 rows x 4 columns]

# %%
result.loc[result['raw_text']==""]
# Out:
#      raw_text        issue sentiment sentiment_all
# 78                   빠른 배송        긍정            긍정
# 79                  섬세한 설치        긍정            긍정
# 96             배송 시간 지정 가능        긍정            긍정
# 97                  튼튼한 기둥        긍정            긍정
# 98                   좋은 화질        긍정            긍정
# ...       ...          ...       ...           ...
# 2430              배터리 지속시간        중립            중립
# 2441               기대되는 제품        긍정            긍정
# 2442              라이브쇼핑 구매        중립            긍정
# 2443                 빠른 배송        긍정            긍정
# 2444             생각보다 큰 크기        중립            긍정
#
# [393 rows x 4 columns]

# %% [markdown]
# ### Step3) theme 생성(군집분석)

# %%
# issue에서 중복 제거
unique_issues = result['issue'].drop_duplicates().tolist()

# %%
len(unique_issues)
# Out:
# 1153

# %%
print(theme_instructions)
# Out:
# 너는 제품 리뷰 키워드를 군집화하고 분류하는 전문가야. 다음 지시사항에 따라 결과를 생성해줘.
# <지시사항>
# 1. 이슈들을 의미적으로 비슷한 그룹으로 나누고, 각 그룹의 공통 테마(theme)를 도출해줘
# 2. 답변은 코드블록이나 마크다운 포맷 없이, 순수한 JSON 포맷으로 제공한다. ```json 같은 형식은 사용하지 않는다.
# </지시사항>

# %%
print(theme_few_shots)
# Out:
# {
#   "화질 만족": ["화질 우수", "좋은 화질", "선명한 화질"],
#   "사용 편의성": ["리모컨 사용 편리", "메뉴 구성 직관적"],
#   "배송 서비스": ["빠른 배송", "친절한 배송"]
# }

# %%
unique_issues
# Out:
# ['좋은 제품',
#  '만족',
#  '빠른 설치 배송',
#  '설치 서비스 만족',
#  '여자친구 만족',
#  '선물 아쉬움',
#  '빠른 배송',
#  '직접 배송 및 설치',
#  '더 큰 화면으로 OTT 시청 좋음',
#  '이동 편리',
#  'OTT 시청',
#  '디자인 만족',
#  '품질 만족',
#  '빠른 설치 안내',
#  '저렴한 가격',
#  '예쁜 디자인',
#  '배송 만족',
#  '충전 번거로움',
#  '대만족',
#  '친절한 설치',
#  '빠른 설치',
#  '좋은 가격',
#  '좋은 서비스',
#  '조립 서비스',
#  '적극 추천',
#  '무겁지만 이동 용이',
#  '우수한 사운드',
#  '우수한 화질',
#  '식사시간 시청',
#  '자기전 시청',
#  '친절한 서비스',
#  '좋은 TV',
#  '제품 만족',
#  '신속한 설치',
#  '설명 만족',
#  '배송 설치',
#  '친절한 배송',
#  '할인',
#  '친절한 설치 기사',
#  '편리한 터치',
#  '부모님 선물 추천',
#  '만족스러운 소비',
#  '추천',
#  '친절한 기사',
#  '빠른 구매',
#  'OTT/유튜브 시청 좋음',
#  '리모컨',
#  '터치 작동',
#  '누워서 사용하기 좋음',
#  'TV 미시청자 추천',
#  '실용성',
#  '훌륭한 디자인',
#  '내구성',
#  'TV없는 가정에서 유용',
#  '편리한 이동',
#  '만족스러운 화질',
#  '만족스러운 음량',
#  '강추',
#  '섬세한 설치',
#  '큰 화면으로 시청',
#  '안전한 배송',
#  '설치 만족',
#  'OTT 시청 편리',
#  '전용티비',
#  '가치 있음',
#  '적기에 상품 구입',
#  '운동 시 사용',
#  '넷플릭스 시청',
#  '배송 시간 지정 가능',
#  '튼튼한 기둥',
#  '좋은 화질',
#  '좋은 소리',
#  '좁은 방에서 스피커 불필요',
#  '아이들 교육에 유용',
#  '지상파 미시청',
#  '유료 어플 필요',
#  '이동식 티비 만족',
#  '편리한 사용',
#  '다양한 기기 사용',
#  '친절한 판매자',
#  '친절한 설치기사',
#  '뒷면 색상',
#  '구매 만족',
#  '거실 시청',
#  '안방 시청',
#  '추천 의사',
#  '잘 사용 중',
#  '구입 망설임',
#  '티비와 다름',
#  '선물로 좋음',
#  '좁은 공간에서 활용 좋음',
#  '만족스러운 구매',
#  '가격 만족',
#  'TV 시청 가능',
#  '이동성',
#  '무선 기능',
#  '깔끔한 디자인',
#  '인테리어와 조화',
#  '깨끗한 화면',
#  '조용한 이동',
#  '편리한 화면 조절',
#  '아기 미디어 노출 방지',
#  '사용 만족',
#  '빠른 배송 및 설치',
#  '스탠바이미 만족',
#  '큰 화면',
#  '평범한 화질',
#  '좋은 사운드',
#  '좋은 구매 기회',
#  '친절한 배송 기사',
#  '깨끗하고 예쁜 제품',
#  '다양한 활용',
#  '좋음',
#  '이쁜 디자인',
#  '친절한 설치 서비스',
#  '최고의 선택',
#  '제품 기대',
#  '가격 가치',
#  '배송 지연',
#  '배송 실수',
#  '비싼 가격',
#  '운동 시 사용 편리',
#  '제품 퀄리티',
#  '전원어댑터 일체화 아쉬움',
#  '편리함',
#  'OTT/유튜브 사용 추천',
#  '느린 웹서핑',
#  '작동 만족',
#  '우수한 설치 서비스',
#  '선물 만족',
#  '디자인 예쁨',
#  '간편함',
#  '구매 욕구',
#  '작업 중 음악 듣기',
#  '정확한 배송',
#  '직접 설치',
#  '배송 일정 조율 가능',
#  '만족스러운 제품',
#  '집에서 사용 적합',
#  '희망 배송일 맞춤',
#  '사전 연락',
#  '심플한 디자인',
#  '무선 사용 가능',
#  '전반적 만족',
#  '깔끔한 설치',
#  '안방에서 높은 활용도',
#  '신세계 경험',
#  '진작 구매 후회',
#  '최고의 제품',
#  '제품 사용 만족',
#  '좋은 디자인',
#  '좋은 음질',
#  '방에서 시청',
#  '적절한 크기',
#  '깔끔한 마감',
#  '터치 스크린',
#  '원하는 날짜에 배송 설치',
#  '실시간 TV 가능',
#  '삶의 질 상승',
#  '늦은 구매 후회',
#  '사용 편리',
#  '괜찮은 화질',
#  '괜찮은 스피커',
#  '매일 사용',
#  '우수한 성능',
#  '스피커 답답함',
#  '직접 조립 서비스',
#  '가격 대비 성능',
#  '비쌈',
#  '임신 선물 만족',
#  '듀얼모니터 사용',
#  'HDMI 케이블 제공',
#  '직관적인 사용 방법',
#  '넷플릭스 시청 만족',
#  '생일선물 서프라이즈 성공',
#  '좋은 상품',
#  '움직이는 27인치 태블릿',
#  '선명한 화질',
#  '부드러운 바퀴',
#  '방에서 TV 시청 가능',
#  '설명 잘해줌',
#  '가격 비교',
#  '인테리어 효과',
#  '성능 만족',
#  '터치 기능',
#  '화면 크기 아쉬움',
#  '높은 가격',
#  'TV 없는 분들 추천',
#  '가벼운 무게',
#  '가격 대비 좋음',
#  '아이가 좋아함',
#  '무난한 사용',
#  '아이의 핸드폰 사용 대체',
#  '생일 선물',
#  '침대에서 사용',
#  '성능 평가 미정',
#  '착한 가격',
#  '친절한 설치 및 사용 설명',
#  '정자세로 시청 가능',
#  '영화 시청',
#  '운동 영상 시청',
#  '집순이에게 필수템',
#  '공간 이동 가능',
#  '화면 크기 적당',
#  '신혼 선물로 적합',
#  '재고 확인 및 배송 일정 체크',
#  '안전한 배송 및 설치',
#  '간단한 세팅과 안내',
#  'LG 제품 만족',
#  '고민 후 구매',
#  '여자친구가 잘 사용',
#  '유용함',
#  '터치스크린 선택',
#  '삶의 질 향상',
#  '좋은 배송',
#  '만족스러운 사용',
#  '숙소에서 편리한 사용',
#  '후회 없는 구매',
#  '터치의 이점',
#  '무선의 이점',
#  '편리한 시청',
#  '라이프 스타일 변화',
#  '방에서 필요시에만 시청',
#  '컴팩트함',
#  '가격 하락',
#  '부모님댁 설치 만족',
#  '스마트폰 시청 어려움',
#  '강연/유튜브/네이버 뉴스 시청',
#  '직접 설치 및 설명',
#  '행사에서 렌탈 활용',
#  '충전 가능',
#  '미라클모닝 활용',
#  'TV 없는 집에서 유용',
#  '판매처 문제',
#  '배송 문제',
#  '사기 의심',
#  '설치 서비스',
#  '친절한 배송기사',
#  '구입 만족',
#  'OTT/유튜브 시청',
#  '깨끗한 화질',
#  '만족스러운 상품',
#  '가족과 다른 콘텐츠 시청',
#  '귀여운 디자인',
#  '서브 용도로 구매',
#  '잘 작동함',
#  '장판에 사람모양 새겨짐',
#  '늦은 배송',
#  '영화 및 자녀 교육용 사용 만족',
#  '아름다운 디자인',
#  '만족스러움',
#  '휴대폰 사용 감소',
#  '반응 속도 개선',
#  '재구매 의향',
#  'OTT 시청 추천',
#  '구입 추천',
#  '생활의 질 향상',
#  '좋은 기능',
#  '좋은 사용 경험',
#  '쉬운 자가설치',
#  '1인가구에 적합',
#  '지정일 방문 설치',
#  '만족도 최고',
#  'TV 미시청',
#  '상품 가치와 퀄리티',
#  '저렴한 구매 방법 발견',
#  '만족스러운 설치 서비스',
#  '주문 후 배송 시간',
#  '오프라인보다 저렴한 가격',
#  '제품 상태 양호',
#  '허위 광고',
#  '무료배송 및 설치 불이행',
#  '리뷰 조작 의심',
#  '고객센터 및 판매자 대응 불만',
#  '아이 학습용',
#  '티비 대용',
#  '높은 활용도',
#  '전반적인 만족',
#  '최대 높이 낮음',
#  '친절한 상담',
#  '직접 배달',
#  '좋은 이동성',
#  '긴 배터리 지속 시간',
#  '좋은 설치',
#  '합리적인 가격',
#  '침대에서 TV 시청',
#  '기사님의 시간 확인 연락',
#  '자세한 기능 설명',
#  '박스 수거',
#  '저렴한 행사 가격',
#  '원룸에서 적합한 사이즈',
#  '식탁에서 보드 게임 사용',
#  '식사 중 음악 사용',
#  '아이들 만족',
#  '어머니 만족',
#  '빠른 방전',
#  '작은 화면',
#  '아쉬운 화질 및 음향',
#  '높은 완성도',
#  '거실 분위기 변화',
#  '무선 편리',
#  '화면 터치',
#  '침대에서 각도 불편',
#  '간편한 사용',
#  '높은 사용만족도',
#  '탁월한 선택',
#  '구매 추천',
#  '딸 선물 만족',
#  '높은 침대에서 편리',
#  '소음 문제',
#  '눈높이 및 각도 조절 용이',
#  '끊김없는 영상 시청',
#  '무게감',
#  '큰 TV 대체',
#  '친절한 설치 및 설명',
#  '합리적 가격',
#  '친구들과 사용 좋음',
#  '개인 사용 좋음',
#  '가족과 함께 사용',
#  '이동 가능',
#  '홈트 편리',
#  '영화 보기 만족',
#  '예쁜 인테리어',
#  'TV없는 신혼집에서 유용',
#  '부모님 선물',
#  '적당한 크기',
#  '구입 고민',
#  '빠른 배달 및 설치',
#  '침실에서 사용 좋음',
#  '신속 설치',
#  '부드러운 이동',
#  '유선 TV 연결 어려움',
#  '좋은 사용감',
#  '좋은 물건',
#  '다양한 쓰임',
#  '스탠바이미 원조',
#  '느린 인터넷',
#  '다른 부분 만족',
#  '좋은 구매 조건',
#  '신속 정확한 배송',
#  '가격대비 최고의 품질',
#  '혁명적 제품',
#  '홈트용으로 만족',
#  '상품 문제 없음',
#  '인테리어 용도',
#  '누워서 시청',
#  '요리하면서 시청',
#  '편리성',
#  '큰 태블릿 같음',
#  '게임 가능',
#  '유튜브 및 넷플릭스 시청',
#  '티비로 인한 싸움 해결',
#  '처음에는 기대보다 실망',
#  '사용할수록 편리',
#  '와이파이 문제',
#  '엘지띵큐앱 기기 연결 문제',
#  '공유기 문제 해결',
#  '카메라 거치대 미포함 아쉬움',
#  '전체적으로 만족',
#  '티비 사용 빈도 증가',
#  '완전 만족',
#  '이동 용이',
#  '쉬운 작동',
#  '빠른 주문',
#  '외국어 영상 교육용',
#  '영상 시청용',
#  '스마트 TV로 교체',
#  '아이들 유튜브 시청',
#  '친절한 설명',
#  '이쁜 인테리어',
#  '설치 빠름',
#  '빠른 답변',
#  '하자 없는 제품',
#  '감사',
#  '잘 사용',
#  '기스난 상품',
#  '반품 경험',
#  '새상품 수령',
#  '상품 만족',
#  '기대 이상',
#  '침대에서 편리한 시청',
#  '가족 만족',
#  '재구매',
#  '큰 화면으로 시청 좋음',
#  '좋은 구매',
#  '직접 배송',
#  'TV 보기 간편',
#  '부모님 사용 만족',
#  '사용 전',
#  '배송 속도',
#  '꼼꼼한 설치',
#  '아주 좋음',
#  '배터리 지속 시간',
#  '무거움',
#  '최고의 가전제품 구매',
#  'TV 없는 환경에서 추천',
#  '선물로 적합',
#  '유용성',
#  '대체공휴일 설치',
#  '디자인',
#  '화질',
#  '쓸모',
#  '완벽한 설치',
#  '누워서 TV 시청',
#  'OTT 상품 결제',
#  '상품 상태 좋음',
#  '필수품',
#  '정확한 설치 날짜',
#  '지정일 배송',
#  '공식인증점 구매 신뢰',
#  '큰 화면으로 영상 시청',
#  '거실과 안방 이동',
#  '충전 및 이동 편리',
#  '미러링 기능',
#  '파티 활용',
#  '최애 상품',
#  '이동형 티비',
#  '이동 시청 가능',
#  '구매대행',
#  '배송업체와 협의 필요',
#  '공급부족으로 인한 배송 지연',
#  '신제품 구매 추천',
#  '편리한 활용도',
#  '이사 전 구매',
#  '또렷한 화면',
#  '아이패드와 비교',
#  '잘 구입했다는 느낌',
#  '명품가전',
#  '공간 절약',
#  '자취생 추천',
#  '설거지할 때 시청',
#  '자기 전 시청',
#  '오리지널 제품 선호',
#  '눈이 편함',
#  'OTT 시청의 질 향상',
#  '안방에서 보기 좋음',
#  '가성비 좋음',
#  '결혼 선물로 적합',
#  '좋은 반응속도',
#  '좋은 가격에 구매',
#  '무선 이용 가능',
#  '스피커 품절 아쉬움',
#  '집순이/집돌이 추천',
#  '리모컨 조작 가능',
#  '깔끔한 배송 및 설치',
#  '드라마 정주행',
#  '새로운 경험',
#  '닌텐도 사용 가능',
#  '스포츠 게임 가능',
#  '유튜브 강의 시청',
#  '딸의 만족',
#  '설치비 포함',
#  '티비와 다른 느낌',
#  '매우 만족',
#  '가정에서 사용 좋음',
#  '우수한 디자인',
#  '긴 배송 시간',
#  '가격 인상',
#  '판매자의 소통 부족',
#  '티비 없는 거실에 적합',
#  '좋은 음량',
#  '완벽한 사이즈',
#  '인테리어 소품으로 좋음',
#  '안전한 배달',
#  '가격',
#  '상품 인기',
#  '배송 어려움',
#  '원하는 날짜에 배송',
#  '오래 걸리는 배송',
#  '친절한 기사님',
#  '영화관 같은 경험',
#  '아이의 집중',
#  '무료배송',
#  '좋은 설치 서비스',
#  '인기 상품',
#  '감사 인사',
#  '제품 사용 의향',
#  '집들이 선물',
#  '최고의 구매',
#  '간단한 시청',
#  '세컨 TV로 사용',
#  '태블릿으로 사용',
#  '영상용으로 적합',
#  '국민템',
#  '사용 편안',
#  '다양한 기능',
#  '기대 이하의 화질',
#  '짧은 무선 사용 시간',
#  '제품 설치 만족',
#  '좋은 품질',
#  '대기 시간',
#  '침대에서 시청',
#  '1인 가구 추천',
#  '하루 종일 시청',
#  '직원 선물 준비',
#  '높은 만족도',
#  '쉬운 미러링',
#  '쉬운 스마트뷰 연결',
#  '지정배송',
#  '집에 잘 어울림',
#  '스피커 추가 구매로 만족도 상승',
#  '좋은 구매 결정',
#  '정확한 설치일',
#  '이즈베스트 업체 만족',
#  '우수한 스피커',
#  '설명 제공',
#  '선물로 만족',
#  '공간 활용',
#  '거실에서 시청 만족',
#  '자유로운 사용',
#  '행사 구매',
#  'TV 없는 거실에 적합',
#  '인테리어 해치지 않음',
#  '공간별 이동 용이',
#  '휴대폰 미러링',
#  '큰 화면으로 유튜브/넷플릭스 시청',
#  '무이자 36개월',
#  '방에서 사용 좋음',
#  '분위기 조성',
#  '캠핑장에서 만족',
#  '다양한 활용 가능',
#  '신속',
#  '정확',
#  '친절',
#  '저렴',
#  '터치 기능 사용 빈도 낮음',
#  '직배송',
#  '설치 및 설명',
#  '행사용으로 적합',
#  '최고의 안방 TV',
#  'TV없는 생활에서 스탠바이미 만족',
#  '예상만큼 좋은 품질',
#  '인터넷 설치 기대',
#  '친절한 설치 및 배송',
#  '할인 구매',
#  '배송 날짜 지정',
#  '깨끗한 설치',
#  'OTT 서비스 다양',
#  '캠핑에서 사용 만족',
#  '가까운 거리에서 화질 저하',
#  '감성적인 디자인',
#  '세심한 화면 구성',
#  '낭랑한 사운드',
#  '편안한 메뉴 구성',
#  '캠핑에서 사용',
#  '가정에서 활용',
#  '체스 놀이',
#  '캠핑장에서 사용',
#  '충동구매',
#  '무게감 있음',
#  '우수한 품질',
#  '이동식 사용 계획',
#  '기능 미사용',
#  '좋아 보임',
#  '서비스 만족',
#  '캠핑장에서 게임',
#  '흐린 화질',
#  '큰 화면 만족',
#  '힐링 경험',
#  '큰 크기',
#  '보통의 화질',
#  '좋은 연결성',
#  '괜찮은 사용성',
#  '작은 Apple Music 사운드',
#  '큰 일반 TV 사운드',
#  '다양한 OTT 지원',
#  'TV 없는 가정에서 유용',
#  '블루투스 스피커 역할',
#  '캠핑용 구매',
#  '튼튼함',
#  '흠잡을 데 없는 화질',
#  '흠잡을 데 없는 사운드',
#  '흠잡을 데 없는 디자인',
#  '캠핑에서 잘 사용',
#  '필수템',
#  '신선한 생산일자',
#  '캠핑 및 가정에서 사용',
#  '내장 게임',
#  '영화 감상 편리',
#  '음악 감상 좋음',
#  '영화 감상 만족',
#  '무겁지만 이동 가능',
#  '이동 시 파손 위험 없음',
#  '가족 게임 가능',
#  '튼튼한 제작',
#  '가격 아쉬움',
#  '풀터치 스크린',
#  '배터리 탑재',
#  '케이스 포함',
#  '포토리뷰 포인트 제공',
#  '가성비 만족',
#  '이동 중 사용',
#  '스피커 업그레이드',
#  '야외용 활용도',
#  '라이브 추가할인',
#  '캠핑에서 만족',
#  '가방케이스 쿠폰 아쉬움',
#  '구매 후 만족',
#  '캠핑 및 외출 시 편리',
#  '활용도 좋음',
#  '낚시 중 사용',
#  '적당한 화질',
#  '빠른 구매 결정 필요',
#  '짱짱한 사운드',
#  '조금 무거움',
#  '캠핑에서 유용',
#  '할인된 가격',
#  '휴대성 좋음',
#  '4K 영상 표현',
#  '애플 에어드롭 기능',
#  '좋은 음향',
#  '오래가는 배터리',
#  '가정에서 만족',
#  '만능 제품',
#  '강력추천',
#  '느린 배송',
#  '티비 대용 사용',
#  '캠핑용 사용',
#  '무선 사용 시간 만족',
#  '캠핑용으로 사용',
#  '무선 사용 시간',
#  '충전 후 이동 가능',
#  '언제 어디서든 사용 가능',
#  '실내 음향기기 사용',
#  '가정에서 사용',
#  '아이 있는 캠핑러 필수템',
#  '마음에 듦',
#  '친절한 답변',
#  'LG 가전제품 구매',
#  'LG 브랜드 신뢰',
#  '가치 초과 만족',
#  '캠핑 기대',
#  '공식 홈페이지 구매',
#  '무겁지만 크고 좋음',
#  '터치 편리',
#  '다용도',
#  '아이들 자제력 도움',
#  '훌륭한 스피커',
#  '가족캠핑에서 편리',
#  '빔프로젝터 대체',
#  '구매 후회 없음',
#  '할인 소식',
#  '축구경기 시청 만족',
#  '재밌고 귀여운 제품',
#  'TV 및 컴퓨터 기능',
#  '캠핑 필수품',
#  '힐링 영상',
#  '안전 배송',
#  '괜찮은 제품',
#  '보기 편함',
#  '휴대성',
#  '상세한 설명',
#  '아쉬운 화질',
#  '배터리 용량',
#  '캠핑용으로 적합',
#  '무게 걱정',
#  '배터리 이해',
#  '가성비 좋은 제품',
#  '저렴한 구매',
#  '친절한 배송사원',
#  'OTT 연동',
#  '캠핑족 필수템',
#  '조카 만족',
#  '적당한 사이즈',
#  '극강의 화질',
#  '편리한 터치스크린',
#  '좋은 케이스 만듬새',
#  '아이와 게임',
#  '힐링영상의 높은 해상도',
#  '좋은 스피커 성능',
#  '좋은 동영상 품질',
#  '무선 이동 가능',
#  '큰 소리',
#  '성능 제한',
#  '어플 부족',
#  '낚시 및 캠핑에서 사용',
#  '흠집 없음',
#  '만족스러운 음질',
#  '차박 기대',
#  '차박 사용',
#  '안방 사용',
#  '다양한 장소에서 사용 가능',
#  '캠핑에서 사용 좋음',
#  '좋은 성능',
#  '아이방에서 사용',
#  '캠핑용 유용',
#  '이동시 유용',
#  '특가 구매',
#  '빠르고 안전한 배송',
#  '집에서 활용도 높음',
#  '차박에 적합',
#  '엘피 감성 디자인',
#  '빔프로젝터보다 우수함',
#  '우수한 터치 반응 속도',
#  '캠핑에서 사용 기대',
#  '스텐바이미go 사용 가능',
#  '캠핑 및 침대에서 사용',
#  '바닥 생활에 적합',
#  '닌텐도 연결 가능',
#  '아이들 게임 가능',
#  '무선 시청 가능',
#  '가족 모두 만족',
#  '문제 없음',
#  '기사님 직접 배송',
#  '만족스러운 사운드',
#  '아쉬운 외관 디자인',
#  'Go의 더 좋은 기능',
#  '설치 불필요',
#  '3일 배송',
#  '짧은 사용시간',
#  '구매후기 강요',
#  '여러 장소에서 사용',
#  '훌륭한 음질',
#  '게임 추가 필요',
#  '리모컨 만족',
#  '캠핑에서 편리한 사용',
#  '충전기와 리모컨 내장',
#  '축구 시청 만족',
#  '게임 기능',
#  '부피 크고 무거움',
#  '캠핑에서 활용도 좋음',
#  '좋은 편의성',
#  '무이자 행사',
#  '다양한 용도',
#  '만족스러운 스피커',
#  '독보적인 디자인',
#  '보관 용이성',
#  '만족스러운 터치스크린',
#  '사진 업로드 문제',
#  '터치스크린 만족',
#  '아이의 만족',
#  '개선된 사운드',
#  '좋은 휴대성',
#  '타기기와 호환',
#  '캠핑용으로 만족',
#  '크기 만족',
#  '간편한 조작',
#  'OTT 기본 설치',
#  '금액대비 만족',
#  '행운과 부유함 기원',
#  '캠핑에서의 사용',
#  '즐거운 추억',
#  '기대만큼 좋은 제품',
#  '어디서든 시청 가능',
#  '구글스토어 지원 아쉬움',
#  '유용한 사용',
#  '편안함',
#  '늦게 받은 것에 대한 후회',
#  '편리한 설정',
#  '영화보기 편리',
#  '집순이에게 적합',
#  '캠핑에서 사용 계획',
#  '집에서 자주 사용',
#  '티비 연결 및 플스 사용',
#  '보드게임 기능 재미',
#  '무겁지만 안정감',
#  '큰 화면과 좋은 화질',
#  '캠핑 필수템',
#  '터치식 만족',
#  '보관 용이',
#  'LG 브랜드 만족',
#  '고급스러움',
#  '괜찮은 음질',
#  '편리한 리모콘',
#  '캠핑 장비 간소화',
#  '생각보다 큰 크기',
#  '휴대용으로 편리',
#  '편리한 가방',
#  '텐트에서 사용',
#  '따뜻한 분위기',
#  '여유로운 캠핑',
#  '룸앤티비 내구성 문제',
#  '휴대용 플레이어',
#  '화질 아쉬움',
#  '캠핑용 번거로움',
#  '튼튼한 케이스',
#  '편리한 터치 화면',
#  '기존 LG 룸앤티비 만족',
#  '캠핑에서 명품급',
#  '고급스러운 디자인',
#  '크고 무거움',
#  '스마트폰 테더링 연결',
#  '기사님 서비스 만족',
#  '캠핑장에서 사용 만족',
#  '올려놓을 곳 필요',
#  '화질 불만족',
#  '캠핑 및 야외 사용 적합',
#  '이동 불편',
#  '스탠바이미고 이동 편리',
#  '환불 불가',
#  '재고 부족',
#  '휴대 가능',
#  '다양한 채널 및 게임 가능',
#  '활용도 높음',
#  '캠핑용으로 최고',
#  '간편한 휴대성',
#  '깨끗하고 선명한 화질',
#  '주변 부러움',
#  '유니크한 디자인',
#  '편리한 휴대',
#  '훌륭한 제품',
#  '우수한 화면',
#  '캠핑 장비로 적합',
#  '캠핑 생활 업그레이드',
#  '화면 만족',
#  '캠핑장에서 사용 계획',
#  '평범함',
#  '집에서 사용 만족',
#  '우수한 스피커 음질',
#  '편리한 리모컨 기능',
#  '캠핑용',
#  '빠른 속도',
#  '리모컨 필요',
#  '좁은 공간에서 사용 가능',
#  '회의용으로 사용',
#  '노트북 및 스마트기기 연동',
#  '다기능적 활용',
#  '가격 유지',
#  '넷플릭스 및 유튜브 사용',
#  '캠핑 사용',
#  '귀한 상품',
#  '소비자 만족',
#  '고퀄리티',
#  'LG 가전 선호',
#  '재구매 의사',
#  '가성비',
#  '가격차이',
#  '스탠바이미Go 추천',
#  '선명한 화면',
#  '여행 및 캠핑장에서 유용',
#  '기다리던 제품 도착',
#  '엘지의 시도 응원',
#  '내장된 게임',
#  '유용한 장작불 화면',
#  '영상 재생 만족',
#  '제품 등록 문제',
#  'LG Thin 어플 등록 가능',
#  '광고 보고 구매',
#  '캠핑 및 여행에서 유용',
#  '감성 인테리어',
#  '편리한 음성지원',
#  '리모컨 보관',
#  '홈카페 활용',
#  '드라마 시청',
#  '유튜브 시청',
#  '아내 선물',
#  '안방에서 만족',
#  '직접 배송 신뢰',
#  '공홈 구매 만족',
#  '스크린 설치 불편함 대비 편리함',
#  '소리 작음',
#  '추억 만들기 기대',
#  '음악으로 카페 분위기 연출',
#  '좋은 사용성',
#  '포장 만족',
#  '가족 사용에 적합',
#  '다양한 쓰임새',
#  '아들이 좋아함',
#  '기대감',
#  '집에서 사용',
#  '유용한 기기',
#  '스마트폰 연동',
#  '홈무비 시청',
#  '성능 괜찮음',
#  'FHD 화질 좋음',
#  '차박 및 캠핑 활용도 높음',
#  '개선된 스피커',
#  '캠핑 느낌',
#  'LG 디스플레이 인정',
#  '좋은 화면',
#  '게임 기능 만족',
#  '음악 만족',
#  '높은 만족감',
#  '세련된 디자인',
#  '리뷰 이벤트',
#  '직배송 만족',
#  '캠핑 사용 기대',
#  '깔끔한 스피커',
#  '깔끔한 모니터',
#  '기대되는 제품',
#  '주변 반응 긍정적',
#  '묵직한 무게',
#  '내구성 좋음',
#  '외부 사용 적음',
#  '좋은 행사',
#  '단단한 제품 만듬새',
#  '집 및 외부에서 사용 가능',
#  '차박에서 사용 기대',
#  '캠핑에서 TV 필요성',
#  '최신 TV 느낌',
#  '아이들과 사용 만족',
#  '여행 및 캠핑에서 사용',
#  '안정감',
#  '라이브 혜택',
#  '포토 이벤트 참여',
#  '개봉 예정',
#  '국내 최저가 구매',
#  '안전한 직배송',
#  '넷플릭스 연결',
#  '무게',
#  '차에서 활용 가능',
#  '캠핑장에서 사용 기대',
#  '빠른 반응속도',
#  '좋은 터치감',
#  '우수한 음질',
#  '집과 외부에서 사용성 좋음',
#  '디자인 좋음',
#  '침대와 소파에서 사용',
#  '닌텐도 연결 사용',
#  '유튜브, 넷플릭스, 쿠팡플레이, 티빙 시청',
#  '자기 전 사용',
#  '다양한 기능 습득 예정',
#  '스탠바이미 Go 추천',
#  '스탠드타입 구매 예정',
#  '세컨티비로 적합',
#  '집에서 불멍 가능',
#  '짧은 배터리 수명',
#  '컴퓨터 모니터로 사용',
#  '캠핑 및 가정에서 사용 만족',
#  '배터리 소모',
#  '아이들과 게임 가능',
#  '편의성',
#  '편리성 의문',
#  '배송 과정 미흡',
#  '스크래치 문제',
#  '커버 필요',
#  '스텐바이미 사용 만족',
#  '스텐바이미고 사용 만족',
#  '행사용 구입',
#  '우수한 제품 퀄리티',
#  '뛰어난 음질',
#  '캠핑용 적합',
#  '집 및 야외 사용',
#  '아이들과 잘 사용',
#  '원하는 날 배송',
#  '만족스러운 소리',
#  '큰 사이즈',
#  '사전 안내 부족',
#  '불쾌한 경험',
#  '꼼꼼한 포장',
#  '어디서나 사용 가능',
#  '인싸 등극',
#  '고객 서비스 만족',
#  '만족스러운 기능',
#  '간단하게 볼만한 제품',
#  '최고',
#  '집에서 영화보기 좋음',
#  '잘 작동',
#  '화질 부족',
#  '기숙사에서 사용',
#  '회사용도 기대',
#  '동영상 시청 만족',
#  '집에서 만족',
#  '피벗 기능',
#  '다양한 영상비율 활용',
#  '일반전원과 배터리전원 지원',
#  '높은 활용성',
#  '선물',
#  '배송 연락',
#  '가격 대비 만족',
#  '케이스 색상 만족',
#  '화질 만족',
#  '터치감 만족',
#  '제품 수령',
#  '배터리 수명',
#  '4K 지원 희망',
#  '공간 활용도 좋음',
#  '다른 용도',
#  '우렁찬 사운드',
#  '실내용과 실외용의 차이',
#  '여행용으로 유용',
#  '캠핑 및 침실에서 사용',
#  '작은 태블릿 화면보다 보기 좋음',
#  '스탠바이미 GO의 매력',
#  '업그레이드된 편리함',
#  '캠핑 및 여행에 적합',
#  '제품 모으는 재미',
#  '프로그램 만족',
#  '싱글 사용 적합',
#  '접어서 보관 가능',
#  '즐거움 증가',
#  '감성 모드',
#  '좋은 스피커',
#  '이동성 만족',
#  '사용 만족도',
#  '추가 구매 의향',
#  '만족스러운 배송 절차',
#  '빠른 반응',
#  '지상파 기능 부족',
#  '견고한 손잡이',
#  '화질 열화',
#  '화면 틸트 기능 불편',
#  '모니터 손상 우려',
#  '사진 로딩 불편',
#  '유튜브 단축키 없음',
#  '배터리 용량 확인 불편',
#  '모니터 손상 위험',
#  '충전 단자 위치 불편',
#  '스크래치 우려',
#  '알람 기능 없음',
#  ...]

# %% [markdown]
# ### batch100

# %%
# 유니크한 이슈들을 GPT API로 분류
themes = []
batch_size = 100  # 한번에 너무 많은 데이터를 보내지 않기 위해 배치 처리
for i in range(0, len(unique_issues), batch_size):
    batch_issues = unique_issues[i:i+batch_size]
    themes.append(classify_issues(', '.join(batch_issues)))

os.system('say "작업이 완료되었습니다."')
# # 배치 결과를 합쳐서 하나의 테마 리스트로 변환
# theme_list = [theme.strip() for theme in ', '.join(themes).split(',')]
# Out:
# 0

# %%
themes
# Out:
# ['{\n  "제품 품질 및 성능": ["좋은 제품", "우수한 사운드", "우수한 화질", "좋은 화질", "좋은 소리", "만족스러운 화질", "만족스러운 음량", "깨끗한 화면"],\n  "디자인 및 인테리어": ["디자인 만족", "예쁜 디자인", "훌륭한 디자인", "깔끔한 디자인", "인테리어와 조화", "뒷면 색상"],\n  "가격 및 가치": ["저렴한 가격", "좋은 가격", "할인", "가격 만족", "가치 있음"],\n  "배송 및 설치 서비스": ["빠른 설치 배송", "설치 서비스 만족", "빠른 배송", "직접 배송 및 설치", "빠른 설치 안내", "배송 만족", "신속한 설치", "배송 설치", "친절한 배송", "친절한 설치 기사", "안전한 배송", "배송 시간 지정 가능", "친절한 설치", "설치 만족", "섬세한 설치"],\n  "사용 편의성": ["이동 편리", "편리한 터치", "터치 작동", "누워서 사용하기 좋음", "편리한 이동", "편리한 사용", "무선 기능", "조용한 이동"],\n  "고객 만족 및 추천": ["만족", "여자친구 만족", "대만족", "적극 추천", "추천", "만족스러운 소비", "강추", "추천 의사", "만족스러운 구매", "구매 만족", "잘 사용 중"],\n  "서비스 및 지원": ["친절한 설치", "친절한 서비스", "친절한 기사", "친절한 판매자", "친절한 설치기사"],\n  "OTT 및 TV 시청": ["더 큰 화면으로 OTT 시청 좋음", "OTT 시청", "OTT/유튜브 시청 좋음", "넷플릭스 시청", "TV 시청 가능", "TV없는 가정에서 유용", "전용티비", "지상파 미시청", "아이들 교육에 유용"],\n  "제품 활용": ["식사시간 시청", "자기전 시청", "운동 시 사용", "거실 시청", "안방 시청", "좁은 공간에서 활용 좋음"],\n  "기타": ["선물 아쉬움", "충전 번거로움", "유료 어플 필요", "좁은 방에서 스피커 불필요", "구입 망설임", "티비와 다름", "선물로 좋음", "다양한 기기 사용", "튼튼한 기둥", "이동식 티비 만족", "내구성"]\n}',
#  '{\n  "화질 및 사운드": ["평범한 화질", "좋은 사운드", "괜찮은 화질", "괜찮은 스피커", "스피커 답답함", "좋은 음질", "선명한 화질"],\n  "디자인 및 외관": ["이쁜 디자인", "디자인 예쁨", "심플한 디자인", "깔끔한 마감", "인테리어 효과", "좋은 디자인"],\n  "사용 편의성": ["편리한 화면 조절", "운동 시 사용 편리", "OTT/유튜브 사용 추천", "작동 만족", "간편함", "직관적인 사용 방법", "터치 스크린", "무선 사용 가능", "사용 편리", "매일 사용", "정자세로 시청 가능", "영화 시청"],\n  "배송 및 설치 서비스": ["빠른 배송 및 설치", "친절한 배송 기사", "친절한 설치 서비스", "우수한 설치 서비스", "정확한 배송", "희망 배송일 맞춤", "사전 연락", "원하는 날짜에 배송 설치", "설명 잘해줌", "직접 설치", "배송 일정 조율 가능", "깨끗하고 예쁜 제품"],\n  "가격 및 가치": ["좋은 구매 기회", "가격 가치", "비싼 가격", "가격 대비 성능", "높은 가격", "착한 가격", "가격 대비 좋음", "비쌈", "가격 비교"],\n  "제품 만족도": ["사용 만족", "스탠바이미 만족", "최고의 선택", "제품 기대", "만족스러운 제품", "전반적 만족", "신세계 경험", "최고의 제품", "제품 사용 만족", "성능 만족", "우수한 성능", "좋은 상품"],\n  "특별한 사용 사례": ["아기 미디어 노출 방지", "아이가 좋아함", "아이의 핸드폰 사용 대체", "넷플릭스 시청 만족", "방에서 시청", "방에서 TV 시청 가능", "안방에서 높은 활용도", "침대에서 사용", "듀얼모니터 사용", "운동 시 사용 편리", "작업 중 음악 듣기", "생일선물 서프라이즈 성공", "임신 선물 만족"],\n  "부정적 경험": ["배송 지연", "배송 실수", "전원어댑터 일체화 아쉬움", "느린 웹서핑", "화면 크기 아쉬움", "비쌈"],\n  "기타": ["다양한 활용", "좋음", "직접 조립 서비스", "설명 잘해줌", "신세계 경험", "진작 구매 후회", "늦은 구매 후회", "HDMI 케이블 제공", "움직이는 27인치 태블릿", "부드러운 바퀴", "TV 없는 분들 추천", "가벼운 무게", "삶의 질 상승"]\n}',
#  '{\n  "사용 편의성 및 만족도": ["운동 영상 시청", "화면 크기 적당", "여자친구가 잘 사용", "유용함", "터치의 이점", "무선의 이점", "편리한 시청", "라이프 스타일 변화", "방에서 필요시에만 시청", "컴팩트함", "OTT/유튜브 시청", "깨끗한 화질", "만족스러운 상품", "가족과 다른 콘텐츠 시청", "귀여운 디자인", "서브 용도로 구매", "잘 작동함", "영화 및 자녀 교육용 사용 만족", "아름다운 디자인", "휴대폰 사용 감소", "반응 속도 개선", "재구매 의향", "OTT 시청 추천", "구입 추천", "생활의 질 향상", "좋은 기능", "좋은 사용 경험", "쉬운 자가설치", "1인가구에 적합", "TV 미시청", "상품 가치와 퀄리티", "높은 활용도", "전반적인 만족", "높은 완성도", "거실 분위기 변화"],\n  "배송 및 설치 서비스": ["재고 확인 및 배송 일정 체크", "안전한 배송 및 설치", "간단한 세팅과 안내", "좋은 배송", "친절한 배송기사", "만족스러운 설치 서비스", "주문 후 배송 시간", "지정일 방문 설치", "기사님의 시간 확인 연락", "박스 수거", "직접 배달"],\n  "구매 및 가격": ["고민 후 구매", "가격 하락", "저렴한 구매 방법 발견", "오프라인보다 저렴한 가격", "저렴한 행사 가격"],\n  "제품 품질 및 브랜드 만족": ["LG 제품 만족", "만족스러운 사용", "구입 만족", "부모님댁 설치 만족", "아이들 만족", "어머니 만족", "제품 상태 양호"],\n  "이동성 및 사용 장소": ["공간 이동 가능", "숙소에서 편리한 사용", "TV 없는 집에서 유용", "원룸에서 적합한 사이즈", "침대에서 TV 시청", "식탁에서 보드 게임 사용", "식사 중 음악 사용"],\n  "고객 서비스 및 문제점": ["판매처 문제", "배송 문제", "사기 의심", "설치 서비스", "허위 광고", "무료배송 및 설치 불이행", "리뷰 조작 의심", "고객센터 및 판매자 대응 불만"],\n  "특정 용도 및 기능": ["강연/유튜브/네이버 뉴스 시청", "미라클모닝 활용", "아이 학습용", "티비 대용"],\n  "배터리 및 충전": ["충전 가능", "긴 배터리 지속 시간", "빠른 방전"],\n  "디자인 및 외관": ["아름다운 디자인", "귀여운 디자인"],\n  "화질 및 음향": ["아쉬운 화질 및 음향"]\n}',
#  '{\n  "사용 편의성": ["무선 편리", "간편한 사용", "높은 사용만족도", "구매 추천", "높은 침대에서 편리", "눈높이 및 각도 조절 용이", "끊김없는 영상 시청", "이동 가능", "홈트 편리", "영화 보기 만족", "침실에서 사용 좋음", "부드러운 이동", "좋은 사용감", "다양한 쓰임", "누워서 시청", "요리하면서 시청", "편리성", "큰 태블릿 같음", "게임 가능", "유튜브 및 넷플릭스 시청", "티비로 인한 싸움 해결", "사용할수록 편리", "전체적으로 만족", "티비 사용 빈도 증가", "완전 만족", "쉬운 작동", "영상 시청용", "아이들 유튜브 시청", "잘 사용", "침대에서 편리한 시청", "가족 만족", "TV 보기 간편", "부모님 사용 만족", "아주 좋음", "배터리 지속 시간", "TV 없는 환경에서 추천"],\n  "제품 만족도": ["높은 사용만족도", "탁월한 선택", "딸 선물 만족", "친구들과 사용 좋음", "개인 사용 좋음", "가족과 함께 사용", "부모님 선물", "좋은 물건", "상품 문제 없음", "기대 이상", "상품 만족", "재구매", "좋은 구매", "최고의 가전제품 구매", "선물로 적합", "유용성"],\n  "설치 및 서비스": ["친절한 설치 및 설명", "빠른 배달 및 설치", "신속 설치", "빠른 주문", "직접 배송", "꼼꼼한 설치", "설치 빠름", "친절한 설명", "빠른 답변", "하자 없는 제품", "새상품 수령", "반품 경험", "대체공휴일 설치"],\n  "가격 및 품질": ["합리적 가격", "가격대비 최고의 품질", "좋은 구매 조건"],\n  "디자인 및 인테리어": ["예쁜 인테리어", "이쁜 인테리어", "디자인"],\n  "기술적 문제": ["소음 문제", "유선 TV 연결 어려움", "느린 인터넷", "와이파이 문제", "엘지띵큐앱 기기 연결 문제", "공유기 문제 해결", "카메라 거치대 미포함 아쉬움"],\n  "기타": ["화면 터치", "침대에서 각도 불편", "무게감", "큰 TV 대체", "스탠바이미 원조", "처음에는 기대보다 실망", "사용 전", "배송 속도", "기스난 상품"]\n}',
#  '{\n  "화질 및 화면 경험": ["화질", "또렷한 화면", "눈이 편함", "기대 이하의 화질", "영화관 같은 경험", "좋은 음량", "완벽한 사이즈", "스포츠 게임 가능", "유튜브 강의 시청", "아이의 집중"],\n  "설치 및 배송 서비스": ["완벽한 설치", "정확한 설치 날짜", "지정일 배송", "배송업체와 협의 필요", "공급부족으로 인한 배송 지연", "깔끔한 배송 및 설치", "긴 배송 시간", "안전한 배달", "원하는 날짜에 배송", "오래 걸리는 배송", "친절한 기사님", "무료배송", "좋은 설치 서비스", "지정배송"],\n  "사용 용도 및 편리성": ["누워서 TV 시청", "큰 화면으로 영상 시청", "거실과 안방 이동", "미러링 기능", "이동형 티비", "이동 시청 가능", "편리한 활용도", "설거지할 때 시청", "자기 전 시청", "안방에서 보기 좋음", "무선 이용 가능", "리모컨 조작 가능", "드라마 정주행", "닌텐도 사용 가능", "침대에서 시청", "하루 종일 시청", "쉬운 미러링", "쉬운 스마트뷰 연결", "집에 잘 어울림"],\n  "구매 및 제품 신뢰": ["OTT 상품 결제", "상품 상태 좋음", "공식인증점 구매 신뢰", "구매대행", "신제품 구매 추천", "잘 구입했다는 느낌", "오리지널 제품 선호", "가성비 좋음", "좋은 가격에 구매", "스피커 품절 아쉬움", "인기 상품", "제품 사용 의향", "최고의 구매", "간단한 시청", "세컨 TV로 사용", "영상용으로 적합", "국민템"],\n  "제품 평가 및 추천": ["쓸모", "필수품", "최애 상품", "이사 전 구매", "아이패드와 비교", "명품가전", "공간 절약", "자취생 추천", "집순이/집돌이 추천", "가정에서 사용 좋음", "우수한 디자인", "인테리어 소품으로 좋음", "상품 인기", "1인 가구 추천", "높은 만족도"],\n  "선물 및 특별한 용도": ["파티 활용", "결혼 선물로 적합", "딸의 만족", "집들이 선물", "직원 선물 준비"],\n  "가격 및 판매자 소통": ["가격 인상", "판매자의 소통 부족"],\n  "감사 및 만족 표현": ["감사 인사", "매우 만족", "제품 설치 만족", "좋은 품질"]\n}',
#  '{\n  "구매 만족도": ["스피커 추가 구매로 만족도 상승", "좋은 구매 결정", "선물로 만족", "행사 구매", "할인 구매", "구매 후 만족", "가성비 만족"],\n  "설치 및 배송 서비스": ["정확한 설치일", "직배송", "친절한 설치 및 배송", "배송 날짜 지정", "신속, 정확, 친절", "깨끗한 설치"],\n  "제품 품질": ["우수한 스피커", "흠잡을 데 없는 화질", "흠잡을 데 없는 사운드", "흠잡을 데 없는 디자인", "우수한 품질", "예상만큼 좋은 품질", "튼튼한 제작"],\n  "사용 경험": ["자유로운 사용", "휴대폰 미러링", "큰 화면으로 유튜브/넷플릭스 시청", "OTT 서비스 다양", "영화 감상 편리", "음악 감상 좋음", "가족 게임 가능", "내장 게임", "큰 화면 만족", "좋은 연결성", "괜찮은 사용성", "TV 없는 생활에서 스탠바이미 만족", "TV 없는 거실에 적합", "캠핑장에서 사용 만족", "캠핑장에서 게임", "캠핑 및 가정에서 사용"],\n  "디자인 및 인테리어": ["인테리어 해치지 않음", "감성적인 디자인", "세심한 화면 구성", "편안한 메뉴 구성"],\n  "이동 및 휴대성": ["공간별 이동 용이", "이동식 사용 계획", "무겁지만 이동 가능", "이동 중 사용", "캠핑 및 외출 시 편리", "야외용 활용도"],\n  "가격 및 금융 옵션": ["무이자 36개월", "가격 아쉬움", "포토리뷰 포인트 제공", "라이브 추가할인"],\n  "특정 용도": ["캠핑용 구매", "캠핑에서 사용", "캠핑장에서 만족", "행사용으로 적합", "필수템"],\n  "제품 구성 및 부가 기능": ["터치 기능 사용 빈도 낮음", "풀터치 스크린", "배터리 탑재", "케이스 포함", "블루투스 스피커 역할"],\n  "사운드 경험": ["낭랑한 사운드", "작은 Apple Music 사운드", "큰 일반 TV 사운드"],\n  "화질 경험": ["흐린 화질", "보통의 화질", "가까운 거리에서 화질 저하", "큰 크기"],\n  "서비스 및 지원": ["서비스 만족", "이즈베스트 업체 만족", "설명 제공", "설치 및 설명"]\n}',
#  '{\n  "캠핑 및 야외 활동": ["낚시 중 사용", "캠핑에서 유용", "캠핑용 사용", "캠핑용으로 사용", "아이 있는 캠핑러 필수템", "가족캠핑에서 편리", "캠핑 필수품", "차박 기대", "차박 사용", "캠핑에서 사용 좋음", "캠핑용 유용", "캠핑에서 사용 기대", "캠핑 및 침대에서 사용", "캠핑족 필수템"],\n  "화질 및 영상 품질": ["적당한 화질", "4K 영상 표현", "아쉬운 화질", "극강의 화질", "좋은 동영상 품질", "힐링영상의 높은 해상도"],\n  "음향 및 사운드 품질": ["짱짱한 사운드", "좋은 음향", "훌륭한 스피커", "큰 소리", "만족스러운 음질", "좋은 스피커 성능"],\n  "휴대성 및 이동성": ["조금 무거움", "휴대성 좋음", "무선 사용 시간 만족", "충전 후 이동 가능", "언제 어디서든 사용 가능", "무선 이동 가능", "이동시 유용", "무게 걱정"],\n  "가격 및 구매": ["빠른 구매 결정 필요", "할인된 가격", "공식 홈페이지 구매", "저렴한 구매", "특가 구매", "할인 소식"],\n  "사용 장소 및 다용도": ["가정에서 만족", "티비 대용 사용", "실내 음향기기 사용", "가정에서 사용", "안방 사용", "아이방에서 사용", "다양한 장소에서 사용 가능", "집에서 활용도 높음", "바닥 생활에 적합"],\n  "브랜드 및 신뢰": ["LG 가전제품 구매", "LG 브랜드 신뢰"],\n  "제품 성능 및 기능": ["만능 제품", "강력추천", "무선 사용 시간", "좋은 성능", "성능 제한", "어플 부족", "스텐바이미go 사용 가능", "닌텐도 연결 가능", "아이들 게임 가능"],\n  "디자인 및 외관": ["엘피 감성 디자인", "좋은 케이스 만듬새", "재밌고 귀여운 제품", "흠집 없음"],\n  "사용자 경험": ["마음에 듦", "친절한 답변", "가치 초과 만족", "구매 후회 없음", "괜찮은 제품", "보기 편함", "상세한 설명"],\n  "배송 서비스": ["느린 배송", "안전 배송", "친절한 배송사원", "빠르고 안전한 배송"],\n  "기타": ["오래가는 배터리", "배터리 용량", "배터리 이해", "우수한 터치 반응 속도", "터치 편리", "편리한 터치스크린", "아이들 자제력 도움", "힐링 영상", "축구경기 시청 만족", "TV 및 컴퓨터 기능", "빔프로젝터 대체", "빔프로젝터보다 우수함"]\n}',
#  '{\n  "사용 편의성": ["설치 불필요", "간편한 조작", "편리한 설정", "편리한 리모콘", "편리한 터치 화면", "편리한 가방", "편리한 휴대", "간편한 휴대성"],\n  "캠핑 및 야외 활용": ["캠핑에서 편리한 사용", "캠핑에서 활용도 좋음", "캠핑용으로 만족", "캠핑에서의 사용", "캠핑에서 사용 계획", "캠핑 필수템", "캠핑 장비 간소화", "캠핑 및 야외 사용 적합", "캠핑용으로 최고"],\n  "사운드 및 음질": ["만족스러운 사운드", "훌륭한 음질", "만족스러운 스피커", "개선된 사운드", "괜찮은 음질"],\n  "디자인 및 외관": ["아쉬운 외관 디자인", "독보적인 디자인", "고급스러운 디자인", "유니크한 디자인"],\n  "화질 및 화면": ["큰 화면과 좋은 화질", "깨끗하고 선명한 화질", "화질 아쉬움", "화질 불만족"],\n  "배송 및 서비스": ["기사님 직접 배송", "3일 배송", "기사님 서비스 만족", "늦게 받은 것에 대한 후회"],\n  "제품 만족도": ["가족 모두 만족", "문제 없음", "금액대비 만족", "기대만큼 좋은 제품", "아이의 만족", "LG 브랜드 만족", "기존 LG 룸앤티비 만족"],\n  "휴대성 및 이동성": ["좋은 휴대성", "휴대 가능", "이동 불편", "스탠바이미고 이동 편리"],\n  "추가 기능 및 호환성": ["Go의 더 좋은 기능", "게임 기능", "타기기와 호환", "OTT 기본 설치", "스마트폰 테더링 연결", "다양한 채널 및 게임 가능"],\n  "보관 및 크기": ["보관 용이성", "크기 만족", "부피 크고 무거움", "생각보다 큰 크기", "크고 무거움", "올려놓을 곳 필요"],\n  "기타": ["구매후기 강요", "사진 업로드 문제", "구글스토어 지원 아쉬움", "환불 불가", "재고 부족", "행운과 부유함 기원", "즐거운 추억", "편안함", "집순이에게 적합", "따뜻한 분위기", "여유로운 캠핑", "룸앤티비 내구성 문제", "튼튼한 케이스", "주변 부러움"]\n}',
#  '{\n  "화면 및 음질 만족": ["우수한 화면", "화면 만족", "우수한 스피커 음질", "선명한 화면", "영상 재생 만족", "FHD 화질 좋음", "좋은 화면", "개선된 스피커", "음악 만족", "깔끔한 스피커", "깔끔한 모니터"],\n  "캠핑 및 여행 활용": ["캠핑 장비로 적합", "캠핑 생활 업그레이드", "캠핑장에서 사용 계획", "캠핑용", "캠핑 사용", "여행 및 캠핑장에서 유용", "캠핑 및 여행에서 유용", "차박 및 캠핑 활용도 높음", "캠핑 느낌", "차박에서 사용 기대", "캠핑에서 TV 필요성", "여행 및 캠핑에서 사용"],\n  "사용 편의성 및 기능": ["편리한 리모컨 기능", "리모컨 필요", "노트북 및 스마트기기 연동", "다기능적 활용", "넷플릭스 및 유튜브 사용", "LG Thin 어플 등록 가능", "편리한 음성지원", "리모컨 보관", "스마트폰 연동", "게임 기능 만족"],\n  "소비자 만족 및 기대": ["훌륭한 제품", "소비자 만족", "고퀄리티", "LG 가전 선호", "재구매 의사", "기다리던 제품 도착", "엘지의 시도 응원", "아내 선물", "안방에서 만족", "직접 배송 신뢰", "공홈 구매 만족", "추억 만들기 기대", "좋은 사용성", "포장 만족", "가족 사용에 적합", "아들이 좋아함", "기대감", "집에서 사용", "유용한 기기", "홈무비 시청", "성능 괜찮음", "높은 만족감", "세련된 디자인", "기대되는 제품", "주변 반응 긍정적", "묵직한 무게", "내구성 좋음", "단단한 제품 만듬새", "집 및 외부에서 사용 가능", "안정감"],\n  "가격 및 가치": ["가성비", "가격 유지", "가격차이", "국내 최저가 구매"],\n  "제품 및 서비스": ["귀한 상품", "리뷰 이벤트", "직배송 만족", "좋은 행사", "라이브 혜택", "포토 이벤트 참여", "개봉 예정", "안전한 직배송"],\n  "기타": ["평범함", "좁은 공간에서 사용 가능", "회의용으로 사용", "드라마 시청", "유튜브 시청", "홈카페 활용", "음악으로 카페 분위기 연출", "스크린 설치 불편함 대비 편리함", "소리 작음", "내장된 게임", "유용한 장작불 화면", "제품 등록 문제", "광고 보고 구매", "외부 사용 적음", "최신 TV 느낌", "넷플릭스 연결", "무게"]\n}',
#  '{\n  "이동성과 사용성": ["차에서 활용 가능", "캠핑장에서 사용 기대", "집과 외부에서 사용성 좋음", "침대와 소파에서 사용", "닌텐도 연결 사용", "집 및 야외 사용", "어디서나 사용 가능", "집에서 영화보기 좋음", "기숙사에서 사용", "회사용도 기대", "여행용으로 유용", "캠핑 및 침실에서 사용", "작은 태블릿 화면보다 보기 좋음", "이동성 만족", "사용 만족도"],\n  "멀티미디어 기능": ["빠른 반응속도", "좋은 터치감", "우수한 음질", "유튜브, 넷플릭스, 쿠팡플레이, 티빙 시청", "동영상 시청 만족", "피벗 기능", "다양한 영상비율 활용", "일반전원과 배터리전원 지원", "4K 지원 희망", "감성 모드", "좋은 스피커", "우렁찬 사운드", "지상파 기능 부족", "화면 틸트 기능 불편", "사진 로딩 불편", "유튜브 단축키 없음", "알람 기능 없음"],\n  "제품 디자인과 품질": ["디자인 좋음", "우수한 제품 퀄리티", "뛰어난 음질", "만족스러운 소리", "큰 사이즈", "화질 만족", "터치감 만족", "케이스 색상 만족", "스탠바이미 GO의 매력", "업그레이드된 편리함", "견고한 손잡이"],\n  "배터리와 전원": ["짧은 배터리 수명", "배터리 소모", "배터리 수명", "배터리 용량 확인 불편"],\n  "사용 환경과 편리성": ["컴퓨터 모니터로 사용", "편의성", "편리성 의문", "높은 활용성", "공간 활용도 좋음", "다른 용도", "실내용과 실외용의 차이", "프로그램 만족", "싱글 사용 적합", "접어서 보관 가능", "즐거움 증가", "추가 구매 의향"],\n  "배송 및 고객 서비스": ["배송 과정 미흡", "원하는 날 배송", "사전 안내 부족", "불쾌한 경험", "꼼꼼한 포장", "고객 서비스 만족", "만족스러운 배송 절차", "배송 연락"],\n  "부품 및 내구성": ["스크래치 문제", "커버 필요", "모니터 손상 우려", "스크래치 우려", "모니터 손상 위험", "충전 단자 위치 불편"],\n  "사용 만족도": ["스텐바이미 사용 만족", "스텐바이미고 사용 만족", "행사용 구입", "만족스러운 기능", "간단하게 볼만한 제품", "최고", "잘 작동", "집에서 만족"],\n  "기타": ["아이들과 게임 가능", "아이들과 잘 사용", "인싸 등극", "선물", "제품 수령", "캠핑 및 가정에서 사용 만족", "캠핑용 적합", "스탠바이미 Go 추천", "스탠드타입 구매 예정", "세컨티비로 적합", "집에서 불멍 가능", "화질 부족", "화질 열화", "프로그램 만족"]\n}',
#  '{\n  "제품 품질 및 성능": ["제품 개발과 판매 긍정적", "완벽한 기기", "견고함", "좋은 내구성", "LG전자 품질 및 성능 신뢰", "엘지전자 제품 추천"],\n  "화질 및 음향": ["좋지 않은 화질", "충분한 화질", "FHD 화질", "화질 개선 필요", "우수한 음량", "리얼한 소리", "충분한 음향"],\n  "사용 편의성": ["터치스크린 사용 편리", "각도 조절 용이", "좋은 터치", "편리한 작동", "리모컨 작동", "엘지싱큐앱 리모컨 조절", "편리한 가방 구성", "터치 딜레이", "좋은 음성인식 기능"],\n  "휴대성과 이동성": ["무선 휴대용 만족", "이동하면서 영상 및 티비 시청", "휴대성 있는 모니터", "캠핑에서 사용 가능", "차박에서 사용 만족", "여행 시 사용", "캠핑에 최적화"],\n  "가족 및 아이들 사용": ["아이들이 좋아함", "가족 사용 만족", "아이들 간의 평화", "재미있는 게임앱", "내장된 부르마블 게임", "아이들과 게임", "아이들에게 인기"],\n  "캠핑 및 외부 사용": ["캠핑 추천", "불멍 용도", "캠핑장에서 인기", "외부 브리핑용 사용", "캠핑장에서 TV 시청 눈치", "캠핑 감성"],\n  "배송 및 서비스": ["원하는 날에 배송", "시간에 맞는 배송", "배송 안내 아쉬움", "안전한 제품 수령", "전문 기사 직접 배송", "친절한 안내"],\n  "기타": ["모니터 크기", "무게 만족", "사이즈 만족", "리모콘 쟁탈전", "대체로 만족", "인터넷, 티비, 어플 호환성 문제", "리모컨 분실 위험 없음", "다양한 OTT 플랫폼", "내장 배터리", "가격 대비 아쉬움", "화면 전송 끊김", "작은 배터리 용량", "스크래치", "반품 귀찮음", "파손에 강함", "화면 크기 업그레이드 희망", "구글 앱스토어 활용 희망", "첫인상", "업무용 구매", "구매 결정", "배터리 충전 상태", "교육용 사용", "광고 영향으로 구매", "다양한 게임", "기본 게임 가능", "구매 강추", "크기", "행복함", "무거운 무게", "무게 수용 가능", "차박에서 작은 화면 불편"]\n}',
#  '{\n  "제품 만족도": ["엘지 신뢰", "LG 제품에 대한 감탄", "가족의 만족", "신랑의 최애템", "엘지 제품 만족", "판매 권장", "대대만족", "기대에 부응"],\n  "사용 편의성": ["향상된 휴대성", "편의성 만족", "리모컨 사용", "터치스크린 편리", "빠른 응답속도", "간단한 게임 가능", "유튜브 가능", "다양한 부가 기능"],\n  "디자인 및 인테리어": ["새집 인테리어와 어울림", "만족스러운 디자인", "아늑한 영화관 느낌"],\n  "이동 및 휴대성": ["무겁지만 이동 편리", "묵직하지만 들 수 있는 무게", "무게 있음", "사무실 휴대용"],\n  "배터리 및 무선 사용": ["무선 사용 시간 짧음", "배터리 지속시간", "배터리 용량 부족"],\n  "캠핑 및 야외 활용": ["캠핑 및 가정에서 활용도 높음", "캠핑에서 아이 만족", "캠핑 및 외출 시 유용", "캠핑에서 적합", "캠핑용 추가 구매", "야외 및 캠핑용 추천", "야외 사용 기대"],\n  "사운드 및 시청 경험": ["영화 시청에 적합", "식사 중 TV 시청", "사운드 만족", "서라운드 모드", "눈 피로감 없음", "아늑한 영화관 느낌"],\n  "구매 및 서비스": ["이사 선물로 적합", "선물용 구매", "라이브쇼핑 구매", "12개월 무이자 혜택"],\n  "배송 관련": ["배송 일정 요청", "배송 확인 불가"],\n  "기능 및 성능": ["화질 차이", "4K 미지원 아쉬움", "많이 활용 가능", "블루투스 스피커 연결", "룸앤티비 업그레이드 느낌"],\n  "어플 및 소프트웨어": ["어플 개선 필요"],\n  "내구성": ["튼튼한 외장"],\n  "기타": ["영어 숙제에 유용"]\n}']

# %%
# 각 theme의 key를 추출하여 총 길이를 계산
total_keys_length = sum(len(json.loads(theme).keys()) for theme in themes)
total_keys_length
# Out:
# 116

# %%
def merge_themes(themes):
    merged_dict = defaultdict(list)  # 리스트를 기본값으로 갖는 defaultdict 생성

    for theme in themes:
        # JSON 문자열을 Python dict로 변환
        theme_dict = json.loads(theme)
        
        # 각 key와 value를 병합
        for key, values in theme_dict.items():
            for value in values:
                if value not in merged_dict[key]:  # 중복된 value가 없을 경우만 추가 todo: 판단의 논리가 필요함.
                    merged_dict[key].append(value)
    
    return dict(merged_dict)  # defaultdict을 일반 dict로 변환하여 반환

# %%
merged_themes = merge_themes(themes)

# %%
result_test = result.copy()

# %%
# 'theme' 컬럼을 생성
result_test['theme'] = result_test['issue'].apply(lambda x: find_theme(merged_themes, x))
result_test
# Out:
#                                                raw_text       issue sentiment  \
# 0                                        조아용 조아용 조아용 ㅎㅎ       좋은 제품        긍정
# 1                                        너무 만족하며 사용중입니다          만족        긍정
# 2         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요    빠른 설치 배송        긍정
# 3         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요   설치 서비스 만족        긍정
# 4                          여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요     여자친구 만족        긍정
# ...                                                 ...         ...       ...
# 2468  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...    야외 사용 기대        긍정
# 2469  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...        대대만족        긍정
# 2470  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...  아늑한 영화관 느낌        긍정
# 2471  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...       이동 편리        긍정
# 2472  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...     캠핑에서 유용        긍정
#
#      sentiment_all        theme
# 0               긍정   제품 품질 및 성능
# 1               긍정   고객 만족 및 추천
# 2               긍정  배송 및 설치 서비스
# 3               긍정  배송 및 설치 서비스
# 4               긍정   고객 만족 및 추천
# ...            ...          ...
# 2468            긍정   캠핑 및 야외 활용
# 2469            긍정       제품 만족도
# 2470            긍정   디자인 및 인테리어
# 2471            긍정       사용 편의성
# 2472            긍정   캠핑 및 야외 활동
#
# [2473 rows x 5 columns]

# %%
result_test['theme'].value_counts()
# Out:
# theme
# 기타             584
# 배송 및 설치 서비스    310
# 제품 품질 및 성능     190
# 사용 편의성         168
# 고객 만족 및 추천     111
#               ...
# 가격 및 판매자 소통      2
# 브랜드 및 신뢰         2
# 배송 관련            2
# 어플 및 소프트웨어       1
# 내구성              1
# Name: count, Length: 82, dtype: int64

# %%
# theme가 기타인 데이터 추출
result_test[result_test['theme'] == '기타']
# Out:
#                                                raw_text    issue sentiment  \
# 5                          여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요   선물 아쉬움        중립
# 14    핸드폰으로 ott를 보다보니 항상 아쉬웠는데 고민고민하다질렀어요~^^ 주문후 다음날...    품질 만족        긍정
# 19                                     충전이 번거롭긴 하지만 대만족  충전 번거로움        부정
# 22    친절하게 설치해주시구 무었보다 빠르게 설치해주셔서 넘 좋았어요 >__< 좋은가격에 ...    빠른 설치        긍정
# 24    친절하게 설치해주시구 무었보다 빠르게 설치해주셔서 넘 좋았어요 >__< 좋은가격에 ...   좋은 서비스        긍정
# ...                                                 ...      ...       ...
# 2440                                       설치 빠르고 좋습니다.    빠른 설치        긍정
# 2445                   외이프 형님 선물로 드렸는데 넘나 만족해하심ㅎ캠핑용~~~~    선물 만족        긍정
# 2454                           너무좋아요 날시원해지면 캠핑 갈 생각에 행복    캠핑 기대        긍정
# 2463  물건 잘 받았습니다 배송도 좋게 보내 주시고 제품도 좋고 조금 아쉬운 게 충전 충정...    제품 만족        긍정
# 2467  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...   다양한 기능        긍정
#
#      sentiment_all theme
# 5               긍정    기타
# 14              긍정    기타
# 19              긍정    기타
# 22              긍정    기타
# 24              긍정    기타
# ...            ...   ...
# 2440            긍정    기타
# 2445            긍정    기타
# 2454            긍정    기타
# 2463            중립    기타
# 2467            긍정    기타
#
# [584 rows x 5 columns]

# %%
# "raw_text" 값에 따른 고유 번호 생성 (0부터 시작).
unique_ids, _ = pd.factorize(result_test['raw_text']) # 인덱스만 사용하므로 두 번째 반환값은 무시

# "tid" 값 생성 (0001, 0002 형태로 고유 번호 할당)
result_test['tid'] = ['text' + str(i+1).zfill(4) for i in unique_ids]

# "tid" 컬럼을 "raw_text" 앞에 삽입
result_test = result_test[['tid'] + [col for col in result_test.columns if col != 'tid']]
result_test
# Out:
#            tid                                           raw_text       issue  \
# 0     text0001                                     조아용 조아용 조아용 ㅎㅎ       좋은 제품
# 1     text0002                                     너무 만족하며 사용중입니다          만족
# 2     text0003      4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요    빠른 설치 배송
# 3     text0003      4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요   설치 서비스 만족
# 4     text0004                       여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요     여자친구 만족
# ...        ...                                                ...         ...
# 2468  text0911  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...    야외 사용 기대
# 2469  text0911  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...        대대만족
# 2470  text0912  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...  아늑한 영화관 느낌
# 2471  text0912  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...       이동 편리
# 2472  text0912  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...     캠핑에서 유용
#
#      sentiment sentiment_all        theme
# 0           긍정            긍정   제품 품질 및 성능
# 1           긍정            긍정   고객 만족 및 추천
# 2           긍정            긍정  배송 및 설치 서비스
# 3           긍정            긍정  배송 및 설치 서비스
# 4           긍정            긍정   고객 만족 및 추천
# ...        ...           ...          ...
# 2468        긍정            긍정   캠핑 및 야외 활용
# 2469        긍정            긍정       제품 만족도
# 2470        긍정            긍정   디자인 및 인테리어
# 2471        긍정            긍정       사용 편의성
# 2472        긍정            긍정   캠핑 및 야외 활동
#
# [2473 rows x 6 columns]

# %%
result_test['raw_text'].nunique()
# Out:
# 912

# %%
result_test.to_pickle('result/제공_네이버쇼핑리뷰_S2_batch100_감성테마.pkl')

# %%
result_test.to_excel('result/제공_네이버쇼핑리뷰_S2_batch100_감성테마.xlsx', index = False)
