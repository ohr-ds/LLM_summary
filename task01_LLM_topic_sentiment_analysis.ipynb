# %% [markdown]
# # 패키지 불러오기

# %%
# !openai --version
# Out:
# openai 1.35.7

# %%
# !pwd
# Out:
# /Users/heungrokoh/python_workspace/work/voucher_paprika

# %%
import os
import time
import yaml
import re
import json
import requests
import pickle

from api_utils import *

from openai import OpenAI
import pandas as pd
import numpy as np
import ipywidgets as widgets # interactive display
from tqdm import tqdm # progress bar
from dotenv import load_dotenv
from collections import defaultdict

# %% [markdown]
# # ENV, Config 파일 읽기

# %%
# .env 파일에서 환경 변수 로드(API 키)
load_dotenv()
# Out:
# True

# %%
# YAML 파일 열기
yaml_path = 'config.yaml' # todo: config 파일과 합치기

with open(yaml_path, 'r') as f:
    config = yaml.safe_load(f)

# gpt prompt 설정
sentiment_instructions = config['gptapi']['sentiment']['instructions']
sentiment_few_shots = config['gptapi']['sentiment']['few_shot_examples']
theme_instructions = config['gptapi']['theme']['instructions']
theme_few_shots = config['gptapi']['theme']['few_shot_examples']

# %% [markdown]
# # 함수 정의(todo: 모듈화)

# %%
# 모듈

def get_response(messages):
    """
    model: 모델 종류
    messages: 사용자의 입력과 모델의 출력을 교환하는 메시지 목록
    max_tokens: 생성될 응답의 최대 길이
    temperature: 생성될 응답의 다양성(0.0 ~ 1.0) 0.0은 가장 확실한 답변을, 1.0은 가장 다양한 답변을 생성
    stream: 응답을 한 번에 반환할지 여부. False로 설정하면 한 번에 반환
    """
    try:
        # client: OpenAI API 인스턴스
        response = client.chat.completions.create(
            model = "gpt-4o",
            messages = messages,
            # max_tokens = 150,
            temperature = 0.5,
            stream = False)
        return response.choices[0].message.content
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# JSON 응답에서 raw_text 항목을 추출하는 함수
def extract_raw_text(content):
    return content.get('raw_text', '')

# JSON 응답에서 issue 항목을 추출하는 함수
def extract_issues(content):
    return content.get('issue', [])

# JSON 응답에서 각 issue에 대한 sentiment 값을 추출하는 함수
def extract_sentiments(content):
    return content.get('sentiment', {})

# JSON 응답에서 sentiment_all 값을 추출하는 함수
def extract_sentiment_all(content):
    return content.get('sentiment_all', '')

# 문자열을 딕셔너리로 변환하는 함수
def convert_to_dict(content):
    try:
        return json.loads(content)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        return None
    
# JSON 데이터를 변환하고 추출된 데이터를 DataFrame으로 변환하는 함수
def convert_to_dataframe(content_list):
    data = []
    
    for content in content_list:
        if not content:
            continue  # content가 None이거나 비어 있을 때 건너뜀
        
        content_dict = convert_to_dict(content)
        if not content_dict:
            continue  # JSON 변환에 실패한 경우 건너뜀
        
        raw_text = extract_raw_text(content_dict)
        issues = extract_issues(content_dict)
        sentiments = extract_sentiments(content_dict)
        sentiment_all = extract_sentiment_all(content_dict)
        
        # 각 issue와 sentiment를 별도로 저장
        for issue, sentiment in sentiments.items():
            data.append({
                "raw_text": raw_text,
                "issue": issue,
                "sentiment": sentiment,
                "sentiment_all": sentiment_all
            })
    
    # 데이터가 있을 경우에만 DataFrame 생성
    if data:
        return pd.DataFrame(data)
    else:
        print("No valid data to create DataFrame.")
        return pd.DataFrame()  # 빈 DataFrame 반환
    
def map_issues_to_themes(issues_list, clustering_response):
    themes = []
    for issues in issues_list:
        issue_themes = set()  # 중복을 방지하기 위해 set 사용
        for issue in issues:
            for theme, issue_group in clustering_response.items():
                if issue in issue_group:
                    issue_themes.add(theme)
        themes.append(", ".join(issue_themes))  # 여러 테마가 있을 경우 ","로 결합
    return themes

# 후처리 함수 정의(리스트, 딕셔너리 형태를 문자열로 변환)
def clean_format(value):
    if isinstance(value, list):
        return ', '.join(value)  # 리스트의 경우 ,로 구분하여 문자열로 변환
    if isinstance(value, dict):
        return ', '.join([f"{k}: {v}" for k, v in value.items()])  # 딕셔너리의 경우 key: value 형식으로 변환
    return value  # 이미 문자열인 경우는 그대로 반환

def classify_issues(issues):
    # 'instructions'는 모델의 행동 방침을 설정하므로 system 메시지에 포함
    messages = [
        {"role": "system", "content": theme_instructions},
        {"role": "user", "content": f"다음 이슈들을 의미적으로 비슷한 그룹으로 나누고, 각 그룹의 공통 테마를 도출해줘: {issues}"},
        {"role": "user", "content": f"예시: {theme_few_shots}"}
    ]
    
    return get_response(messages)

# themes 리스트의 각 JSON 문자열을 dict 형태로 변환하여 병합하는 함수
def merge_themes(themes):
    merged_dict = defaultdict(list)  # 리스트를 기본값으로 갖는 defaultdict 생성

    for theme in themes:
        # JSON 문자열을 Python dict로 변환
        theme_dict = json.loads(theme)
        
        # 각 key와 value를 병합
        for key, values in theme_dict.items():
            for value in values:
                if value not in merged_dict[key]:  # 중복된 value가 없을 경우만 추가
                    merged_dict[key].append(value)
    
    return dict(merged_dict)  # defaultdict을 일반 dict로 변환하여 반환

# 'theme' 컬럼을 생성하는 함수(이슈를 테마로 매핑)
def find_theme(merged_themes, issue):
    for theme, issues in merged_themes.items():
        if issue in issues:
            return theme
    return '기타'  # 해당하는 theme이 없을 경우 '기타'로 표시

# %% [markdown]
# # 인스턴스 생성

# %%
# OpenAI API 클라이언트 생성
client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))

# %% [markdown]
# # 파일 읽기

# %%
# 처리할 데이터
df = pd.read_csv('data/제공/제공_네이버쇼핑리뷰.csv')
df.head()
# Out:
#                                               내용      구매처  평점       작성날짜  \
# 0                                 조아용 조아용 조아용 ㅎㅎ  오아시스486   5  24.05.15.
# 1                                 너무 만족하며 사용중입니다     Ader   5  24.05.15.
# 2  4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요     Ader   5  24.05.15.
# 3                   여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요     Ader   5  24.05.15.
# 4                                   살까말까 했는데 좋아요     11번가   4  24.05.15.
#
#         사용자     상품
# 0  rorn****  스탠바이미
# 1  arde****  스탠바이미
# 2  jeon****  스탠바이미
# 3  pjw9****  스탠바이미
# 4  m0******  스탠바이미

# %% [markdown]
# # 적용 영역

# %% [markdown]
# ## Step 1) gpt api 호출

# %%
text_apply = df['내용']

# %%
print(sentiment_instructions)
# Out:
# 넌 글을 요약하는 전문가야. 어떤 제품에 대한 리뷰 원문(raw_text)을 주면 다음 지시사항에 따라 예시와 같이 결과를 생성해줘.
# <지시사항>
# 1. issue는 원문의 주요 사항을 요약한 것입니다. 동일하거나 유사한 표현은 하나의 issue로 통합합니다. 예: “좋은 화질”, “뛰어난 화질” → “우수한 화질”, “가정 및 캠핑에서 사용” → “캠핑 및 가정에서 사용”.
# 2. 각 issue에 대해 감정 분석을 수행하고 sentiment로 표현합니다.
# 3. sentiment는 긍정, 부정, 중립 중 하나로 표시하며, 명확한 감정 평가가 어려운 경우 중립으로 처리합니다.
# 4. 응답은 순수 JSON 형식으로만 제공하며, 코드블록이나 마크다운 포맷은 사용하지 않습니다.
# </지시사항>

# %%
print(sentiment_few_shots)
# Out:
# <예시>
# {
#   "raw_text": "자취하는데 뭔 티비야 .. 하면서 노트북이나 패드로 유튜브, ott 시청했었는데 확실히 더 큰 화면으로 보니까 너무 조아요설거지하거나 가구 배치 바꿀 때도 쉽게 움직여서 이동시킬 수 있으니까 정말 좋습니다..삶의 질이 향상됐어요 ㅎㅎ",
#   "issue": [
#     "더 큰 화면으로 OTT 시청 좋음",
#     "이동 편리"
#   ],
#   "sentiment": {
#     "더 큰 화면으로 OTT 시청 좋음": "긍정",
#     "이동 편리": "긍정"
#   },
#   "sentiment_all": "긍정"
# },
# {
#   "raw_text": "핸드폰으로 ott를 보다보니 항상 아쉬웠는데 고민고민하다질렀어요~^^ 주문후 다음날 오전에 배송설치했고 생각한대로 디자인이나 품질 맘에들어요",
#   "issue": [
#     "OTT 시청",
#     "빠른 배송",
#     "디자인 만족",
#     "품질 만족"
#   ],
#   "sentiment": {
#     "OTT 시청": "중립",
#     "빠른 배송": "긍정",
#     "디자인 만족": "긍정",
#     "품질 만족": "긍정"
#   },
#   "sentiment_all": "긍정"
# },
# {
#   "raw_text": "너무 좋아요무겁지만 바퀴가 있어 이동이 용이 하고사운드,화질등 나무랄게 없어요",
#   "issue": [
#     "무겁지만 이동 용이",
#     "우수한 사운드",
#     "우수한 화질"
#   ],
#   "sentiment": {
#     "무겁지만 이동 용이": "중립",
#     "우수한 사운드": "긍정",
#     "우수한 화질": "긍정"
#   },
#   "sentiment_all": "긍정"
# },
# {
#   "raw_text": "밥 먹을때 자기전에 이동하면서 보고있는데 너무 편하고 좋아요",
#   "issue": [
#     "이동 편리",
#     "식사시간 시청",
#     "자기전 시청"
#   ],
#   "sentiment": {
#     "이동 편리": "긍정",
#     "식사시간 시청": "중립",
#     "자기전 시청": "중립"
#   },
#   "sentiment_all": "긍정"
# },
# {
#   "raw_text": "ott 유튜브만 보는분들에게 적극추천 리모컨으로도 터치로도 작동 잘됩니다~",
#   "issue": [
#     "OTT/유튜브 시청 좋음",
#     "리모컨",
#     "터치 작동"
#   ],
#   "sentiment": {
#     "OTT/유튜브 시청 좋음": "긍정",
#     "리모컨": "긍정",
#     "터치 작동": "긍정"
#   },
#   "sentiment_all": "긍정"
# },
# {
#   "raw_text": "TV 잘 안보시는 분들은 스탠바이미 추천드립니다!",
#   "issue": [
#     "TV 미시청자 추천"
#   ],
#   "sentiment": {
#     "TV 미시청자 추천": "긍정"
#   },
#   "sentiment_all": "긍정"
# },
# {
#   "raw_text": "매우 실용적이고 디자인 및 내구성도 훌륭해보입니다. TV 없는 가정에서는 매우 유용하게 쓰입니다. 이동도 쉬워서 편리하고 화질이나 음량도 만족스럽습니다. 망설이는 분들께 강추합니다.",
#   "issue": [
#     "실용성",
#     "훌륭한 디자인",
#     "내구성",
#     "TV없는 가정에서 유용",
#     "편리한 이동",
#     "만족스러운 화질",
#     "음량",
#     "강추"
#   ],
#   "sentiment": {
#     "실용성": "긍정",
#     "훌륭한 디자인": "긍정",
#     "내구성": "긍정",
#     "TV없는 가정에서 유용": "긍정",
#     "편리한 이동": "긍정",
#     "만족스러운 화질": "긍정",
#     "음량": "긍정",
#     "강추": "긍정"
#   },
#   "sentiment_all": "긍정"
# },
# {
#   "raw_text": "저렴한 가격에 배송 잘 받았어요진작에 살걸 그랬어요너무좋아요",
#   "issue": [
#     "저렴한 가격",
#     "배송 만족",
#     "좋은 제품"
#   ],
#   "sentiment": {
#     "저렴한 가격": "긍정",
#     "배송 만족": "긍정",
#     "좋은 제품": "긍정"
#   },
#   "sentiment_all": "긍정"
# },
# {
#   "raw_text": "캠핑의 질이 수직 상승했습니다. 룸앤티비랑 고민하다가 이걸로 선택했는데 탁월한 선택입니다. 소리도 빵빵하고 화질도 좋습니다. 너무 무거운게 약간 불편하지만 캠핑장에서이런 티비를 볼 수 있다는게 너무 좋아요.",
#   "issue": [
#     "좋은 소리",
#     "좋은 화질",
#     "무거움",
#     "캠핑장에서 만족"
#   ],
#   "sentiment": {
#     "좋은 소리": "긍정",
#     "좋은 화질": "긍정",
#     "무거움": "부정",
#     "캠핑장에서 만족": "긍정"
#   },
#   "sentiment_all": "긍정"
# },
# {
#   "raw_text": "이동하기편하고 작은핸드폰으로 유튜브보는것보다 훨씬조코 편하네요 인터넷 티비 게임까지 할수 잇는 컴퓨터라고 생각하고 사용하려고 합니다 제품이 무게만 가볍다면 정말완벽할 꺼라고 생각합니다 너무 무거워서 아이나 여자는 움직이기 힘드네요",
#   "issue": [
#     "이동 편리",
#     "유튜브",
#     "인터넷",
#     "티비",
#     "게임 가능",
#     "무거움"
#   ],
#   "sentiment": {
#     "이동 편리": "긍정",
#     "유튜브": "긍정",
#     "인터넷": "긍정",
#     "티비": "긍정",
#     "게임 가능": "긍정",
#     "무거움": "긍정"
#   },
#   "sentiment_all": "긍정"
# }
# </예시>

# %%
# 응답들을 저장할 리스트
content_list = []

total_iterations = len(text_apply)

with tqdm(total=total_iterations) as pbar:
    for i, text in enumerate(text_apply):

        # (Step 1) 각 raw_text에 대해 issue와 sentiment 추출
        input_raw_text = text
        system_message = {"role": "system", "content": sentiment_instructions}
        user_message = {"role": "user", "content": f"{sentiment_few_shots}\n<raw_text>\n{input_raw_text}\n</raw_text>"}
        messages = [system_message, user_message]

        # GPT-4로부터 응답 받기
        content = get_response(messages)
        if not content:
            pbar.update(1)
            time.sleep(1)
            continue
        
        # 응답을 리스트에 저장
        content_list.append((content, input_raw_text))
        
        pbar.update(1)
        time.sleep(1)
# Out:
# 100%|██████████| 1000/1000 [47:21<00:00,  2.84s/it]

# %% [markdown]
# ### 답변 dataframe 변환

# %%
# 답변 변환

data_list = []

for content, original_raw_text in content_list:
    parsed_content = convert_to_dict(content)

    raw_text = extract_raw_text(parsed_content)
    if raw_text == "": # raw_text가 비어있는 경우 원본 텍스트로 대체
        raw_text = original_raw_text
    issues = extract_issues(parsed_content) if parsed_content else []
    sentiments = extract_sentiments(parsed_content) if parsed_content else {}
    sentiment_all = extract_sentiment_all(parsed_content) if parsed_content else ""

    for issue in issues:
        sentiment = sentiments.get(issue, 'Unknown')
        data_entry = {
            "raw_text": raw_text,
            "issue": issue,
            "sentiment": sentiment,
            "sentiment_all": sentiment_all
        }
        data_list.append(data_entry)

result_s1 = pd.DataFrame(data_list)
result_s1
# Out:
#                                                raw_text       issue sentiment  \
# 0                                        조아용 조아용 조아용 ㅎㅎ       좋은 제품        긍정
# 1                                        너무 만족하며 사용중입니다       사용 만족        긍정
# 2         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요    빠른 설치 배송        긍정
# 3         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요   설치 서비스 만족        긍정
# 4                          여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요     여자친구 만족        긍정
# ...                                                 ...         ...       ...
# 2476  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...    야외 사용 기대        중립
# 2477  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...        대대만족        긍정
# 2478  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...  아늑한 영화관 느낌        긍정
# 2479  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...       이동 편리        긍정
# 2480  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...     캠핑에서 유용        긍정
#
#      sentiment_all
# 0               긍정
# 1               긍정
# 2               긍정
# 3               긍정
# 4               긍정
# ...            ...
# 2476            긍정
# 2477            긍정
# 2478            긍정
# 2479            긍정
# 2480            긍정
#
# [2481 rows x 4 columns]

# %%
# 결과 중간 저장
result_s1.to_pickle('result/제공_네이버쇼핑리뷰_S1_감성분석.pkl')
result_s1.to_excel('result/제공_네이버쇼핑리뷰_S1_감성분석.xlsx', index=False)

# %% [markdown]
# ## Step 2) theme 생성(군집분석)

# %%
# issue에서 중복 제거
unique_issues = result_s1['issue'].drop_duplicates().tolist()

# %%
# 이슈 갯수
len(unique_issues)
# Out:
# 1157

# %%
print(theme_instructions)
# Out:
# 너는 제품 리뷰 키워드를 군집화하고 분류하는 전문가야. 다음 지시사항에 따라 결과를 생성해줘.
# <지시사항>
# 1. 이슈들을 의미적으로 비슷한 그룹으로 나누고, 각 그룹의 공통 테마(theme)를 도출해줘
# 2. 답변은 코드블록이나 마크다운 포맷 없이, 순수한 JSON 포맷으로 제공한다. ```json 같은 형식은 사용하지 않는다.
# </지시사항>

# %%
print(theme_few_shots)
# Out:
# {
#   "화질 만족": ["화질 우수", "좋은 화질", "선명한 화질"],
#   "사용 편의성": ["리모컨 사용 편리", "메뉴 구성 직관적"],
#   "배송 서비스": ["빠른 배송", "친절한 배송"]
# }

# %% [markdown]
# ### Batch 100

# %%
# 유니크한 이슈들을 GPT API로 분류
themes = []
batch_size = 100  # 한번에 너무 많은 데이터를 보내지 않기 위해 배치 처리
for i in range(0, len(unique_issues), batch_size):
    batch_issues = unique_issues[i:i+batch_size]
    themes.append(classify_issues(', '.join(batch_issues)))

os.system('say "작업이 완료되었습니다."')
# # 배치 결과를 합쳐서 하나의 테마 리스트로 변환
# theme_list = [theme.strip() for theme in ', '.join(themes).split(',')]
# Out:
# 0

# %%
themes
# Out:
# ['{\n  "제품 품질 및 성능": ["좋은 제품", "품질 만족", "우수한 사운드", "우수한 화질", "좋은 화질", "짱짱한 사운드", "좋은 소리", "튼튼한 기둥", "내구성", "만족스러운 화질", "좋은 TV", "상품 만족", "만족스러운 소비", "제품 만족"],\n  "디자인 및 외관": ["디자인 만족", "예쁜 디자인", "이쁜 디자인", "훌륭한 디자인", "깔끔한 디자인", "뒷면 색상"],\n  "가격 및 가치": ["저렴한 가격", "좋은 가격", "많은 할인", "가격 대비 만족", "가격 만족"],\n  "설치 및 배송 서비스": ["빠른 설치 배송", "설치 서비스 만족", "직접 배송 및 설치", "친절한 설치", "친절한 설치 서비스", "친절한 설치기사", "섬세한 안전 설치", "안전한 배송", "설치 만족", "배송 및 설치 만족", "신속한 설치", "빠른 설치 안내", "친절한 서비스", "친절한 기사", "친절한 배송", "배송 만족", "설명 만족", "배송 시간 지정 가능"],\n  "사용 편의성 및 이동성": ["이동 편리", "무겁지만 이동 용이", "편리한 터치", "터치 작동", "방에서 사용 편리", "편리한 이동", "무선 이동 편리", "이동성", "무선", "편리한 사용", "이동식 티비 만족"],\n  "OTT 및 콘텐츠 시청": ["더 큰 화면으로 OTT 시청 좋음", "OTT 시청", "OTT/유튜브 시청 좋음", "OTT 시청 편리", "넷플릭스 시청 좋음", "TV 시청 가능"],\n  "사용자 만족 및 추천": ["사용 만족", "여자친구 만족", "대만족", "적극 추천", "추천", "추천 의사", "만족", "만족스러운 구매", "구매 만족", "잘 사용 중", "만족스러운 소비", "강추"],\n  "특정 상황 및 용도": ["생일 선물로 좋음", "선물로 좋음", "부모님 선물 적합", "TV 미시청자 추천", "운동 중 사용 좋음", "아이들 교육에 도움", "좁은 공간에서 활용 좋음", "좁은 방에서 스피커 불필요", "TV없는 가정에서 유용"],\n  "기타": ["충전 번거로움", "지상파 시청 불가", "유료 어플 필요", "여러 기기 사용", "판매자 친절", "구입 망설임", "티비와 다름", "식사시간 시청", "자기전 시청", "전용 티비 사용", "적기에 제품 구입"]\n}',
#  '{\n  "디자인 및 인테리어": ["인테리어와 잘 어울림", "디자인", "심플한 디자인", "인테리어 효과", "좋은 디자인"],\n  "화질 및 화면": ["깨끗한 화면", "화질 중립", "FHD 화질 만족", "괜찮은 화질", "선명한 화질", "작은 화면"],\n  "사운드 및 음질": ["사운드 만족", "우수한 음질", "괜찮은 스피커", "스피커 답답함"],\n  "배송 및 설치 서비스": ["제품 수령", "빠른 배송 및 설치", "친절한 배송 기사", "친절한 설치 기사", "배송 지연", "배송 실수", "정확한 배송", "희망 배송일 맞춤", "사전 연락", "친절한 배송 및 설치", "친절한 설치 및 설명"],\n  "제품 만족도": ["좋은 구매 기회", "돈이 아깝지 않음", "만족스러운 제품", "최고의 선택", "제품에 대한 긍정적 기대", "전반적 만족", "삶의 질 상승", "구매 후회", "구매 욕구", "좋은 상품", "좋은 구매"],\n  "가격 및 성능": ["비싼 가격", "우수한 제품 퀄리티", "가격 대비 성능", "비쌈", "가격이 비쌈", "좋은 성능", "우수한 성능"],\n  "사용 편의성": ["편리한 화면 조절", "편리함", "작동 잘됨", "간편함", "사용 편리", "직관적인 사용 방법"],\n  "특정 용도 및 기능": ["아기 미디어 노출 방지", "TV 없는 가정에서 유용", "OTT/유튜브 사용자 추천", "이동 사용 추천", "운동 시 사용", "작업 중 음악 청취", "넷플릭스 시청 만족", "영상 시청으로 자세 개선", "실시간 TV 가능", "TV 없는 분들에게 추천"],\n  "이동 및 설치": ["조용한 이동", "이동 용이", "이동 가능한 27인치 태블릿", "부드러운 바퀴", "직접 설치", "직접 조립 서비스"],\n  "선물 및 특별한 경우": ["선물 만족", "선물로 만족", "임신 선물로 만족", "생일 선물 성공", "생일 선물"],\n  "기타": ["전원어댑터 일체화 아쉬움", "듀얼모니터 사용", "HDMI 케이블 제공", "터치 스크린", "터치 기능", "무선 사용 가능", "아이의 만족", "아이가 잘 이용", "성능 불확실", "친절한 판매자", "매일 사용", "혼자 사용하기 적당한 크기", "마감 만족", "높은 활용도", "안방에서 높은 활용도", "집에서 사용하기 좋음", "구매 시기 후회", "설치 설명 만족", "느린 웹서핑", "깔끔한 설치", "배송 일정 조율 가능", "원하는 날짜에 배송 설치", "가격 비교 후 구매", "무난한 사용", "가벼운 무게"]\n}',
#  '{\n  "사용 편의성": ["간단한 세팅과 안내", "편리한 사용 경험", "터치 및 무선의 이점", "자가 설치 쉬움", "침대에서 TV 시청", "필요한 기능 설명", "간편한 사용", "이동의 편리함"],\n  "제품 만족도": ["만족스러운 사용", "잘 사용", "유용함", "전반적인 만족", "높은 만족도", "재구매 의향", "구매 추천", "생활 향상", "전체 만족", "어머니 만족", "높은 사용만족도"],\n  "화질 및 음향": ["깨끗한 화질", "좋은 음질", "화질 아쉬움", "음향 아쉬움"],\n  "배송 및 설치": ["안전한 배송 및 설치", "배송 시간", "직접 설치 및 설명", "설치 서비스", "만족스러운 설치 서비스", "지정일 방문 설치", "하자 없음", "엘지 직접 배송", "박스 수거"],\n  "가격 및 구매": ["가격 하락", "최저가 구매", "저렴한 구매 방법 발견", "합리적인 가격", "비싼 금액대"],\n  "제품 디자인 및 기능": ["컴팩트함", "귀여운 디자인", "컴팩트한 디자인", "디자인 훌륭함", "완성도"],\n  "라이프 스타일 변화": ["영화 시청", "운동 영상 활용", "집순이에게 필수템", "신혼 선물로 적합", "삶의 질 향상", "라이프 스타일 변화", "영화 및 교육용 사용 만족", "아이 학습용", "티비 대용", "식사 중 음악 사용", "보드 게임 중 사용", "아이들이 좋아함"],\n  "제품 기능": ["터치스크린 선택", "큰 화면으로 아이들에게 보여주기 좋음", "충전 가능", "미라클모닝 활용", "좋은 기능", "무선 편리", "화면 터치", "큰 화면"],\n  "부정적인 경험": ["불만족스러운 판매처", "배송 문제", "사기 의심", "허위 광고", "무료 배송 및 설치 미제공", "고객센터 및 판매자 대응 불만", "빠른 방전"]\n}',
#  '{\n  "제품 신뢰 및 만족": ["탁월한 선택", "LG 제품 신뢰", "구매 후회 없음", "좋은 사용감", "좋은 물건", "전반적으로 만족", "재구매 의사", "기대 이상", "좋아요", "잘 산 가전템", "없이는 못 살아", "괜찮은 제품"],\n  "사용 편의성": ["안방 침대에서 편리", "눈높이 및 각도 조절", "끊김없는 영상 시청", "적당한 무게감", "큰 TV 대신 사용", "이동 가능", "홈트 편리", "영화보기 적합", "적당한 크기", "침실에서 사용 좋음", "부드러운 이동", "사용할수록 편리", "쉬운 작동", "영상 시청용 활용", "스마트 티비로 교체", "침대에서 편리한 시청", "방에서 편리한 시청", "큰 화면으로 시청 좋음", "TV 보기 간편", "침대에서 사용"],\n  "가격 및 가치": ["착한 가격", "합리적 가격", "가격 대비 최고의 품질", "좋은 구매 조건"],\n  "가족 및 선물": ["친구들 및 혼자 사용", "가족과 함께 사용", "TV없는 신혼집에서 유용", "신혼부부 사용", "부모님 선물 만족", "가족 만족", "부모님 사용 만족", "신혼부부 선물로 좋음"],\n  "설치 및 배송": ["신속 설치", "신속 정확한 배송", "설치 빠름", "빠른 답변", "제품 상태 양호", "꼼꼼한 설치", "완벽한 설치", "직접 배송", "대체공휴일 설치"],\n  "디자인 및 인테리어": ["예쁜 인테리어", "디자인 예쁨", "아름다운 디자인", "인테리어에 좋음", "이쁜 인테리어", "디자인 좋음"],\n  "기능 및 활용": ["다양한 용도", "스탠바이미 우수", "다른 기능 만족", "홈트용 만족", "누워서 시청", "요리하면서 시청", "큰 태블릿처럼 사용", "게임 가능", "유튜브 시청", "넷플릭스 시청", "가족 간의 티비 싸움 해결", "외국어 영상 교육용 활용"],\n  "문제 및 불만": ["소음", "유선 TV 연결 방법 어려움", "느린 인터넷", "와이파이 문제", "기기 연결 문제", "카메라 거치대 미제공", "처음 실망", "배터리 수명 짧음", "높은 매트에서 이동 어려움", "무거움", "평범한 화질", "평범한 쓸모", "기스난 상품 수령", "반품 후 새상품 수령"],\n  "기타": ["자주 사용하지 않음", "늦은 구매 후회", "상품 문제 없음", "선물로 구입", "감사", "2대째 사용 중"]\n}',
#  '{\n  "편리한 사용 경험": ["누워서 티비 보기 좋음", "이동형 티비 만족", "이동하면서 시청 가능", "편리한 활용도", "침대 위에서 사용", "간단한 사용", "쉬운 미러링", "스마트뷰 연결 용이", "리모컨 조작 가능"],\n  "구매 및 배송 만족": ["정확한 날짜에 설치", "지정일 배송", "친절한 구매 경험", "공식인증점 구매 신뢰", "깔끔한 배송 및 설치", "빠른 조립", "안전한 배달", "빠른 문의 답장", "문의 답변 만족", "무료배송", "설치비 포함", "지정배송", "친절한 기사님", "이즈베스트 업체 만족"],\n  "제품 품질 및 성능": ["상품 하자 없음", "큰 화면으로 영상 시청", "또렷한 화면", "좋은 사운드", "우수한 디자인", "완벽한 음량", "완벽한 사이즈", "좋은 반응속도", "명품가전", "우수한 스피커", "스피커 추가 구매로 만족도 상승", "품질 좋음"],\n  "사용 환경 및 활용도": ["거실 및 안방에서 사용", "침대 및 거실에서 사용", "안방에서 보기 좋음", "설거지할 때 시청", "자기 전 시청", "거실에 적합", "가정에서 사용 좋음", "영화관 같은 경험", "드라마 정주행", "유튜브 강의", "닌텐도 사용 가능", "TV 없는 집에서 시청 질 향상", "TV없는 거실에 적합", "집과 잘 어울림"],\n  "구매 이유 및 추천": ["필요성 인식", "필수품", "자취생 추천", "1인가구 추천", "최애 상품", "국민템", "애완TV", "세컨 TV", "영상용", "유용성", "결혼 선물로 적합", "집들이 선물", "연말 선물 준비", "감사의 표현"],\n  "가격 및 가치": ["가성비", "가격 경쟁력", "좋은 품질", "좋은 구매 결정", "최고의 구매"],\n  "기타": ["OTT 상품 결제", "미러링 기능", "연말 파티 사용", "구매대행", "배송업체 문의 필요", "공급 부족", "이사 전 구입", "삼탠과 비교불가", "오리지널 제품 선호", "눈 편안함", "긴 배송 시간", "판매자의 배송 연기 공지 부족", "받기 어려움", "구매 대기", "역사에 관심 많은 초딩 집중", "인테리어 소품", "스피커 품절 아쉬움", "짧은 무선 사용 시간", "티비와 다른 느낌"]\n}',
#  '{\n  "설치 및 서비스 만족": ["직접 설치 서비스", "만족스러운 설치", "신속한 서비스", "정확한 서비스", "친절한 설치 및 배송 과정", "깨끗한 설치", "직배송", "배송 날짜 지정"],\n  "제품 만족도": ["스탠바이미 만족", "좋아함", "최고의 선물", "만족스러운 가전", "스탠바이미 사용 만족", "예상한 만큼 좋음", "서비스 만족", "성능 만족", "구매 후 만족", "가성비 만족"],\n  "공간 및 이동 활용": ["공간 활용", "TV 없는 거실에서 유용", "인테리어에 적합", "공간 이동 용이", "캠핑장에서 만족", "캠핑에서 사용 좋음", "캠핑장에서 사용", "캠핑장에서 닌텐도 연결", "캠핑 및 가정에서 사용", "캠핑에서 잘 사용", "캠핑용 구매", "캠핑 및 이동 시 편리", "야외용 활용도 좋음", "낚시 중 사용", "캠핑에서 유용"],\n  "시청 및 엔터테인먼트": ["거실에서 시청", "방에서 시청", "자유로운 사용", "큰 화면으로 유튜브 및 넷플릭스 시청", "OTT 이용에 신세계 경험", "유튜브 영상 감탄", "다양한 OTT 서비스", "LG 채널 무료 시청 가능", "TV 역할", "블루투스 스피커 역할", "편리한 영화 시청", "음악 듣기 좋음", "내장 게임", "가족끼리 게임 가능"],\n  "기능 및 성능": ["터치 기능 사용 빈도 낮음", "5세대 인공지능 알파 7 탑재", "돌비 미지원", "좋은 연결성", "풀터치 스크린", "배터리 탑재", "스피커 업그레이드", "무게감 있음", "묵직함", "무겁지만 튼튼", "튼튼한 제작", "이동 시 파손 위험 없음"],\n  "디자인 및 감성": ["감성적인 디자인", "편안한 메뉴 구성", "세심한 화면 구성", "낭랑한 사운드", "작은 사운드 (Apple Music)", "큰 사운드 (일반 TV)"],\n  "가격 및 구매": ["무이자 36개월", "할인 구매", "가격 고민", "빠른 구매 필요성", "라이브 추가 할인", "가방케이스 쿠폰 아쉬움"],\n  "기타": ["휴대폰 미러링", "인터넷 설치 기대", "신선한 생산일자", "포토리뷰 포인트", "사용 미경험", "좋아보임", "흐린 화질", "가정에서 체스 활용", "어른들 힐링", "아이들 만족", "크기 큼", "보통 화질", "적당한 화질", "다양한 활용 가능"]\n}',
#  '{\n  "가격 및 구매": ["할인된 가격", "저렴한 구매", "특가 구매", "가격 대비 가성비 좋음", "높은 가격", "공식 홈페이지 구매"],\n  "휴대성 및 이동성": ["휴대성 좋음", "무선 이동성", "이동시 유용", "무겁지만 이동 가능", "크기 만족", "큰 크기", "무게 걱정"],\n  "캠핑 및 야외 사용": ["캠핑용 사용", "캠핑러 필수템", "캠핑에서 기대", "캠핑에서 편리", "캠핑 필수품", "캠핑용 적합", "캠핑족 필수템", "낚시 및 캠핑에 적합", "캠핑의 즐거움 증가", "캠핑장에서 사용 가능"],\n  "가정 및 실내 사용": ["가정에서 유용", "가정에서 잘 사용", "아이 있는 가정에 적합", "아이방에서 사용 좋음", "안방에서 사용", "실내 음향기기 사용"],\n  "제품 성능 및 품질": ["4K 영상 표현", "우수한 음향", "음악 및 영화 감상", "우수한 동영상 품질", "고해상도 힐링영상", "큰 화면 만족", "우수한 화질", "아쉬운 화질", "성능 부족"],\n  "사용 만족도": ["구매 결정 만족", "강력추천", "마음에 드는 제품", "만족스러운 음질", "가족 모두 사용 만족", "딸이 만족", "조카 만족", "충동구매"],\n  "기능 및 특징": ["애플 에어드롭 기능", "무선 사용 시간 만족", "3시간 무선 사용", "OTT 연동", "리모콘", "터치스크린", "닌텐도 연결 가능", "스텐바이미go 사용 만족"],\n  "배송 및 서비스": ["느린 배송", "친절한 답변", "친절한 배송사원", "빠르고 안전한 배송", "친절한 배송기사"],\n  "디자인 및 외관": ["재미있고 귀여운 제품", "엘피 감성 디자인", "좋은 케이스 만듬새", "튼튼함"],\n  "기타": ["시간과 장소 제약 없음", "다양한 장소에서 사용 가능", "아이들 자제력 도움", "차박 기대", "차박 사용", "대형견과 함께 사용 가능", "판매 응원", "판매 권장", "감사 인사"]\n}',
#  '{\n  "사운드 및 음질 만족": ["만족스러운 사운드", "훌륭한 음질", "좋은 스피커", "좋아진 사운드", "괜찮은 음질", "좋은 음향"],\n  "캠핑 및 야외 활용": ["캠핑에서 만족", "캠핑에서 사용 편리", "캠핑에서 활용도 좋음", "캠핑장에서 최고의 제품", "캠핑 필수 아이템", "텐트에서 잘 사용", "여유로운 캠핑", "캠핑용으로 최고"],\n  "디자인 및 외관": ["외관 디자인 아쉬움", "독보적인 디자인", "고급스러운 디자인", "깔끔함", "유니크한 디자인"],\n  "제품 크기 및 휴대성": ["부피 크고 무거움", "보관 용이", "생각보다 큰 크기", "휴대용으로 편리", "편리한 가방", "번거로운 가방 사용", "스탠바이미 이동 불편", "스탠바이미고 이동 편리", "휴대 가능", "간편한 휴대성"],\n  "기능 및 편의성": ["Go의 우수한 기능", "설치 불필요", "리모컨 만족", "내장 충전기 및 리모컨", "터치스크린 만족", "터치스크린", "간편한 조작", "OTT 기본 설치", "편리한 설정", "편리한 터치 화면", "스마트폰 테더링 연결", "다양한 채널 및 게임 가능"],\n  "사용 경험 및 만족도": ["완전 만족", "아이 만족", "기대만큼 좋은 제품", "어디서든 시청 가능", "유용한 사용", "높은 인기", "만족스러운 디자인", "편안함", "즐거운 추억", "행운 기원", "LG 브랜드 만족"],\n  "기타": ["3일 소요된 수령", "구매후기 강요", "다른 TV 시청", "게임 추가 필요", "축구 시청 만족", "작업실에서 사용", "플스 연결", "보드게임 기능", "안정감", "룸앤티비 내구성 문제", "화질 개선 필요", "기존 LG 룸앤티비 사용 만족", "기사님 서비스 만족", "올려놓을 곳 필요", "환불 불가", "재고 부족"]\n}',
#  '{\n  "휴대성과 캠핑 활용": ["편리한 휴대성", "캠핑 생활 업그레이드", "캠핑용", "캠핑 사용", "여행 및 캠핑장에서 유용", "캠핑 필수템", "캠핑 및 여행에서 유용", "피크닉 및 캠핑에서 유용", "차박 및 캠핑 활용도 높음", "캠핑 느낌", "캠핑용으로 좋음", "캠핑에서 TV 사용 만족", "캠핑에 사용 계획", "여행 및 캠핑에서 사용"],\n  "화면과 음질": ["좋은 화면", "쨍한 화면", "선명한 화면", "좋은 스피커 음질", "넷플릭스 및 유튜브 잘 나옴", "향상된 스피커", "깔끔한 스피커와 모니터"],\n  "사용성 및 기능": ["편리한 리모컨 기능", "리모컨 필요", "회의용 책상에서 사용", "노트북 및 스마트기기 연동", "프리젠테이션 가능", "음악 및 동영상 감상", "실내외 다기능 활용", "음성지원", "리모컨 보관 용이", "홈카페 활용", "드라마/유튜브 시청", "스마트폰 연동", "게임 기능", "음악 기능"],\n  "제품 만족도": ["훌륭한 제품", "평범함", "소비자 만족", "고퀄리티 상품", "실물 만족", "가족 모두 만족", "다양한 활용", "선물용 구매", "안방에서 만족", "공홈 구매 만족", "작은 소리", "사용 후기 신뢰", "추억 만들기", "음악 재생으로 카페 분위기", "좋은 사용성", "포장 만족", "가족 사용 만족", "다들 만족", "아들의 만족", "기대감", "집에서 잘 사용", "유용한 기기", "성능 괜찮음", "구입 만족", "가성비 좋음", "고민 후 구매 만족", "높은 만족감", "세련된 디자인", "리뷰 이벤트", "직배송 만족", "기대되는 제품", "생각보다 좋은 제품"],\n  "브랜드 및 가격": ["LG 가전 선호", "가격 차이", "엘지의 시도 응원", "가격 유지"],\n  "구매 및 배송 경험": ["크리스마스 선물로 구매", "기다리던 제품 도착", "광고 후 즉시 구매", "좋은 행사", "좋은 배송"],\n  "내구성과 디자인": ["무게", "무게 묵직함", "내구성 기대", "외부 사용 적음", "단단한 만듬새", "아이들이 건드리지 못할 무게감", "최신 TV 느낌"],\n  "제품 등록 및 앱 기능": ["제품 등록 불편함", "LG Thin 앱에서 기기 등록 가능"]\n}',
#  '{\n  "사용 만족도": ["장기간 사용 만족", "스텐바이미 사용 만족", "스텐바이미고 만족", "제품에 대한 만족", "기능 만족", "사용 만족도", "제품 수령 만족"],\n  "구매 및 가격": ["국내 최저가 구매", "좋은 기회에 구매", "세컨티비로 구매 만족", "선물용 구매 만족", "온라인 구매", "가격 비쌈"],\n  "편의성 및 활용성": ["빠른 반응속도", "좋은 터치감", "뛰어난 사용성", "편의성", "편리성 모호", "간단하게 볼 수 있는 제품", "높은 활용성", "터치 편리", "감성 모드 만족"],\n  "다양한 사용 환경": ["TV 없는 집에서 유용", "차에서 활용 가능", "캠핑장에서 사용 기대", "침대 및 소파에서 사용", "가정 및 야외에서 사용", "아이들과 함께 사용", "기숙사 사용 좋음", "회사용도", "캠핑 및 침실에서 사용", "여행용", "싱글에게 적합"],\n  "기능 및 연결성": ["넷플릭스 연결", "닌텐도 연결", "유튜브/넷플릭스/쿠팡플레이/티빙 시청", "컴퓨터 모니터로 연결 사용", "다양한 영상비율 활용", "일반전원 및 배터리 전원 지원", "4K 지원 필요", "지상파 기능 필요"],\n  "이동성 및 설치": ["스탠바이미 Go 추천", "스탠드타입 구매 예정", "어디서나 사용 가능", "접어서 보관 가능", "견고한 손잡이"],\n  "배송 및 포장": ["안전한 직배송", "미흡한 배송과정", "스크래치 발생", "사전 연락 없음", "꼼꼼한 포장", "배송 연락", "만족스러운 배송 및 절차"],\n  "배터리 및 전원": ["짧은 배터리 수명", "배터리 수명 개선 필요", "배터리 용량 확인 불편"],\n  "사운드 및 화질": ["뛰어난 음질", "만족스러운 소리", "사운드 우수", "우렁찬 사운드", "화질 열화"],\n  "제품 디자인 및 크기": ["큰 사이즈", "케이스 색상 만족"],\n  "기타": ["포토 이벤트 참여", "퇴근 후 개봉 예정", "행사용으로 적합", "신세계 경험", "강력 추천", "원하는 날 배송", "인싸 등극 쉬움", "고객 서비스", "즐거움 증가", "괜찮은 프로그램", "제품 수집의 재미", "업그레이드로 인한 편리함"]\n}',
#  '{\n  "제품 설계 및 디자인": ["최고의 디자인", "견고함", "좋은 터치", "편리한 작동", "화면 크기 업그레이드 희망", "외관상 첫느낌"],\n  "이동 및 휴대성": ["좋은 이동성", "무게 만족", "캠핑에 최적화", "휴대성 있는 모니터 구매", "편리한 가방 구성", "이동하며 영상/티비 시청"],\n  "사용 편의성 및 기능": ["터치스크린 조작 용이", "각도 조절 용이", "리모컨 작동 쉬움", "터치 딜레이", "편리한 작동", "엘지싱큐앱 리모콘 조절"],\n  "화질 및 음질": ["충분한 화질", "화질 보통", "가격 대비 FHD 화질 아쉬움", "아쉬운 음질", "좋은 음량", "리얼한 소리", "BGM 재생 좋음"],\n  "배송 및 서비스": ["시간 맞춘 배송", "원하는 날에 친절한 배송", "배송 안내 아쉬움", "전문기사 배송", "안전한 제품 수령"],\n  "제품 내구성 및 안전": ["모니터 손상 주의 필요", "스크래치 방지 필요", "스크래치", "파손에 강함", "좋은 내구성"],\n  "사용자 경험 및 만족도": ["완벽한 기기", "대체로 만족", "돈 아깝지 않음", "전체적인 만족", "행복함", "현재 만족", "좋음"],\n  "제품 활용성 및 용도": ["실내외 OTT 시청 편리", "인터넷 사용 가능", "티비 기능", "캠핑장에서 사용 만족", "외부 브리핑용으로 사용", "교육용 사용", "업무용 구매"],\n  "게임 및 엔터테인먼트": ["닌텐도 스위치 게임", "부르마블 게임", "재미있는 게임앱", "기본게임 가능", "다양한 게임"],\n  "배터리 및 전원": ["내장 배터리", "작은 배터리 용량", "배터리 충전 상태"],\n  "제품 및 브랜드 이미지": ["LG전자의 시도", "LG전자 품질과 성능 만족", "광고 영향으로 구매", "광고 효과"],\n  "사용자 불만 및 개선점": ["충전 단자 위치 불편", "부족한 어플", "어플 호환성 문제", "화면 전송 끊김", "사용 안내 아쉬움", "반품 귀찮음"]\n}',
#  '{\n  "제품 추천 및 신뢰": ["엘지전자 제품 추천", "엘지 제품 신뢰", "LG 제품에 대한 감탄", "이사 선물로 적합", "캠핑러 추천"],\n  "휴대성과 이동성": ["무선 휴대용", "향상된 휴대성", "무겁지만 이동 편리", "묵직하지만 들 수 있음"],\n  "사용 경험 및 기능": ["좋은 음성인식 기능", "사진과 동일한 품질", "다양한 부가 기능", "터치스크린 작동 편리", "만족스러운 사용 경험", "간단한 게임 가능", "빠른 응답속도", "업그레이드된 느낌"],\n  "캠핑 및 야외 활용": ["차박에서 큰 화면 필요", "캠핑 및 가정에서 활용 가능", "캠핑에서 아이 만족", "캠핑장에서 적합", "캠핑용 추가 구매", "캠핑에서 좋음", "야외 및 캠핑용 가능성", "야외 사용 기대"],\n  "배터리 및 전원": ["무선 사용 시간 짧음", "배터리 지속시간", "배터리 용량 적음"],\n  "화질 및 화면": ["화질 차이", "4K 미지원 아쉬움", "눈 피로감 없음", "아늑한 영화관 느낌"],\n  "기타": ["닌텐도 스위치 연결", "어플 개선 필요", "배송일정 확인 불가", "라이브쇼필 구매"],\n  "가정 및 일상 활용": ["영화 시청에 적합", "아이들 영화 시청", "식사 중 TV 시청", "방에서 영상 시청 만족", "유튜브 가능", "영어 숙제에 유용", "사무실 휴대용"],\n  "음향 및 연결": ["블루투스 스피커 연결", "서라운드 모드"],\n  "기대 및 만족도": ["기대만큼 좋음", "기대", "기다린 제품", "대대만족"],\n  "구매 및 혜택": ["신랑의 최애템", "12개월 무이자 혜택"]\n}']

# %%
# 각 theme의 key를 추출하여 총 길이를 계산
total_keys_length = sum(len(json.loads(theme).keys()) for theme in themes)
total_keys_length
# Out:
# 112

# %%
merged_themes = merge_themes(themes)

# %%
result_s2 = result_s1.copy()

# %%
# 'theme' 컬럼을 생성
result_s2['theme'] = result_s2['issue'].apply(lambda x: find_theme(merged_themes, x))
result_s2
# Out:
#                                                raw_text       issue sentiment  \
# 0                                        조아용 조아용 조아용 ㅎㅎ       좋은 제품        긍정
# 1                                        너무 만족하며 사용중입니다       사용 만족        긍정
# 2         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요    빠른 설치 배송        긍정
# 3         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요   설치 서비스 만족        긍정
# 4                          여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요     여자친구 만족        긍정
# ...                                                 ...         ...       ...
# 2476  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...    야외 사용 기대        중립
# 2477  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...        대대만족        긍정
# 2478  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...  아늑한 영화관 느낌        긍정
# 2479  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...       이동 편리        긍정
# 2480  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...     캠핑에서 유용        긍정
#
#      sentiment_all         theme
# 0               긍정    제품 품질 및 성능
# 1               긍정   사용자 만족 및 추천
# 2               긍정   설치 및 배송 서비스
# 3               긍정   설치 및 배송 서비스
# 4               긍정   사용자 만족 및 추천
# ...            ...           ...
# 2476            긍정    캠핑 및 야외 활용
# 2477            긍정      기대 및 만족도
# 2478            긍정       화질 및 화면
# 2479            긍정  사용 편의성 및 이동성
# 2480            긍정    공간 및 이동 활용
#
# [2481 rows x 5 columns]

# %% [markdown]
# ### tid 생성

# %%
# "raw_text" 값에 따른 고유 번호 생성 (0부터 시작).
unique_ids, _ = pd.factorize(result_s2['raw_text']) # 인덱스만 사용하므로 두 번째 반환값은 무시

# "tid" 값 생성 (0001, 0002 형태로 고유 번호 할당)
result_s2['tid'] = ['text' + str(i+1).zfill(4) for i in unique_ids]

# "tid" 컬럼을 "raw_text" 앞에 삽입
result_s2 = result_s2[['tid'] + [col for col in result_s2.columns if col != 'tid']]
result_s2
# Out:
#            tid                                           raw_text       issue  \
# 0     text0001                                     조아용 조아용 조아용 ㅎㅎ       좋은 제품
# 1     text0002                                     너무 만족하며 사용중입니다       사용 만족
# 2     text0003      4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요    빠른 설치 배송
# 3     text0003      4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요   설치 서비스 만족
# 4     text0004                       여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요     여자친구 만족
# ...        ...                                                ...         ...
# 2476  text0991  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...    야외 사용 기대
# 2477  text0991  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...        대대만족
# 2478  text0992  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...  아늑한 영화관 느낌
# 2479  text0992  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...       이동 편리
# 2480  text0992  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...     캠핑에서 유용
#
#      sentiment sentiment_all         theme
# 0           긍정            긍정    제품 품질 및 성능
# 1           긍정            긍정   사용자 만족 및 추천
# 2           긍정            긍정   설치 및 배송 서비스
# 3           긍정            긍정   설치 및 배송 서비스
# 4           긍정            긍정   사용자 만족 및 추천
# ...        ...           ...           ...
# 2476        중립            긍정    캠핑 및 야외 활용
# 2477        긍정            긍정      기대 및 만족도
# 2478        긍정            긍정       화질 및 화면
# 2479        긍정            긍정  사용 편의성 및 이동성
# 2480        긍정            긍정    공간 및 이동 활용
#
# [2481 rows x 6 columns]

# %%
result_s2.to_pickle('result/제공_네이버쇼핑리뷰_S2_감성테마.pkl')
result_s2.to_excel('result/제공_네이버쇼핑리뷰_S2_감성테마.xlsx', index = False)
