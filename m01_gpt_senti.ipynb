# %% [markdown]
# # 패키지 불러오기

# %%
# !openai --version
# Out:
# openai 1.35.7

# %%
import os
import time
import yaml
import re
import json
import requests
import pickle

from openai import OpenAI
import pandas as pd
import numpy as np
import ipywidgets as widgets # interactive display
from tqdm import tqdm # progress bar
from dotenv import load_dotenv

# %% [markdown]
# # ENV, Config 파일 읽기

# %%
# .env 파일에서 환경 변수 로드(API 키)
load_dotenv()
# Out:
# True

# %%
# YAML 파일 열기
yaml_path = 'config.yaml' # todo: config 파일과 합치기

with open(yaml_path, 'r') as f:
    config = yaml.safe_load(f)

# gpt prompt 설정
sentiment_instructions = config['gptapi']['sentiment']['instructions']
sentiment_few_shots = config['gptapi']['sentiment']['few_shot_examples']
theme_instructions = config['gptapi']['theme']['instructions']
theme_few_shots = config['gptapi']['theme']['few_shot_examples']

# %% [markdown]
# # 인스턴스 생성

# %%
# OpenAI API 클라이언트 생성
client = OpenAI(api_key=os.getenv('OPENAI_API_KEY'))

# %% [markdown]
# # 함수 정의

# %%
def get_response(messages):
    """
    model: 모델 종류
    messages: 사용자의 입력과 모델의 출력을 교환하는 메시지 목록
    max_tokens: 생성될 응답의 최대 길이
    temperature: 생성될 응답의 다양성(0.0 ~ 1.0) 0.0은 가장 확실한 답변을, 1.0은 가장 다양한 답변을 생성
    stream: 응답을 한 번에 반환할지 여부. False로 설정하면 한 번에 반환
    """
    try:
        response = client.chat.completions.create(
            model = "gpt-4o",
            messages = messages,
            # max_tokens = 150,
            temperature = 0.5,
            stream = False)
        return response.choices[0].message.content
    except Exception as e:
        print(f"An error occurred: {e}")
        return None

# JSON 응답에서 raw_text 항목을 추출하는 함수
def extract_raw_text(content):
    return content.get('raw_text', '')

# JSON 응답에서 issue 항목을 추출하는 함수
def extract_issues(content):
    return content.get('issue', [])

# JSON 응답에서 각 issue에 대한 sentiment 값을 추출하는 함수
def extract_sentiments(content):
    return content.get('sentiment', {})

# JSON 응답에서 sentiment_all 값을 추출하는 함수
def extract_sentiment_all(content):
    return content.get('sentiment_all', '')

# 문자열을 딕셔너리로 변환하는 함수
def convert_to_dict(content):
    try:
        return json.loads(content)
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        return None
    
# JSON 데이터를 변환하고 추출된 데이터를 DataFrame으로 변환하는 함수
def convert_to_dataframe(content_list):
    data = []
    
    for content in content_list:
        if not content:
            continue  # content가 None이거나 비어 있을 때 건너뜀
        
        content_dict = convert_to_dict(content)
        if not content_dict:
            continue  # JSON 변환에 실패한 경우 건너뜀
        
        raw_text = extract_raw_text(content_dict)
        issues = extract_issues(content_dict)
        sentiments = extract_sentiments(content_dict)
        sentiment_all = extract_sentiment_all(content_dict)
        
        # 각 issue와 sentiment를 별도로 저장
        for issue, sentiment in sentiments.items():
            data.append({
                "raw_text": raw_text,
                "issue": issue,
                "sentiment": sentiment,
                "sentiment_all": sentiment_all
            })
    
    # 데이터가 있을 경우에만 DataFrame 생성
    if data:
        return pd.DataFrame(data)
    else:
        print("No valid data to create DataFrame.")
        return pd.DataFrame()  # 빈 DataFrame 반환
    
def map_issues_to_themes(issues_list, clustering_response):
    themes = []
    for issues in issues_list:
        issue_themes = set()  # 중복을 방지하기 위해 set 사용
        for issue in issues:
            for theme, issue_group in clustering_response.items():
                if issue in issue_group:
                    issue_themes.add(theme)
        themes.append(", ".join(issue_themes))  # 여러 테마가 있을 경우 ","로 결합
    return themes

# 후처리 함수 정의(리스트, 딕셔너리 형태를 문자열로 변환)
def clean_format(value):
    if isinstance(value, list):
        return ', '.join(value)  # 리스트의 경우 ,로 구분하여 문자열로 변환
    if isinstance(value, dict):
        return ', '.join([f"{k}: {v}" for k, v in value.items()])  # 딕셔너리의 경우 key: value 형식으로 변환
    return value  # 이미 문자열인 경우는 그대로 반환

# %% [markdown]
# # 파일 읽기

# %% [markdown]
# # test 영역

# %%
# 처리할 데이터
df = pd.read_csv('data/제공/제공_네이버쇼핑리뷰.csv')
df.head()
# Out:
#                                               내용      구매처  평점       작성날짜  \
# 0                                 조아용 조아용 조아용 ㅎㅎ  오아시스486   5  24.05.15.
# 1                                 너무 만족하며 사용중입니다     Ader   5  24.05.15.
# 2  4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요     Ader   5  24.05.15.
# 3                   여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요     Ader   5  24.05.15.
# 4                                   살까말까 했는데 좋아요     11번가   4  24.05.15.
#
#         사용자     상품
# 0  rorn****  스탠바이미
# 1  arde****  스탠바이미
# 2  jeon****  스탠바이미
# 3  pjw9****  스탠바이미
# 4  m0******  스탠바이미

# %% [markdown]
# ## test

# %%
test = df['내용'][:20]

# %%
print(test[8])
# Out:
# 주문하고 바로 설치안내문자오더니 토요일에 기사님 오셔서 설치해주셨어요 싸게 잘 샀습니다

# %%
input_raw_text = test[8]
system_message = {"role": "system", "content": sentiment_instructions}
user_message = {"role": "user", "content": f"{sentiment_few_shots}\n<raw_text>\n{input_raw_text}\n</raw_text>"}
messages = [system_message, user_message]
content = get_response(messages)

# %%
print(content)
# Out:
# {
#   "raw_text": "주문하고 바로 설치안내문자오더니 토요일에 기사님 오셔서 설치해주셨어요 싸게 잘 샀습니다",
#   "issue": [
#     "빠른 설치 안내",
#     "저렴한 가격"
#   ],
#   "sentiment": {
#     "빠른 설치 안내": "긍정",
#     "저렴한 가격": "긍정"
#   },
#   "sentiment_all": "긍정"
# }

# %%
content
# Out:
# '{\n  "raw_text": "주문하고 바로 설치안내문자오더니 토요일에 기사님 오셔서 설치해주셨어요 싸게 잘 샀습니다",\n  "issue": [\n    "빠른 설치 안내",\n    "저렴한 가격"\n  ],\n  "sentiment": {\n    "빠른 설치 안내": "긍정",\n    "저렴한 가격": "긍정"\n  },\n  "sentiment_all": "긍정"\n}'

# %%
content_dict = convert_to_dict(content)

# %%
raw_text = extract_raw_text(content_dict)
issues = extract_issues(content_dict)
sentiments = extract_sentiments(content_dict)
sentiment_all = extract_sentiment_all(content_dict)

# %%
raw_text
# Out:
# '주문하고 바로 설치안내문자오더니 토요일에 기사님 오셔서 설치해주셨어요 싸게 잘 샀습니다'

# %%
result = convert_to_dataframe([content])

# %%
result
# Out:
#        tid                                          raw_text     issue  \
# 0  FB-0001  주문하고 바로 설치안내문자오더니 토요일에 기사님 오셔서 설치해주셨어요 싸게 잘 샀습니다  빠른 설치 안내
# 1  FB-0001  주문하고 바로 설치안내문자오더니 토요일에 기사님 오셔서 설치해주셨어요 싸게 잘 샀습니다    저렴한 가격
#
#   sentiment sentiment_all
# 0        긍정            긍정
# 1        긍정            긍정

# %%
test = df['내용'][:20]
print(test)
# Out:
# 0                                        조아용 조아용 조아용 ㅎㅎ
# 1                                        너무 만족하며 사용중입니다
# 2         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요
# 3                          여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요
# 4                                          살까말까 했는데 좋아요
# 5                    빠른 배송 감사합니다. LG에서 직잡 배송/설치 했습니다. .
# 6     자취하는데 뭔 티비야 .. 하면서 노트북이나 패드로 유튜브, ott 시청했었는데 확...
# 7     핸드폰으로 ott를 보다보니 항상 아쉬웠는데 고민고민하다질렀어요~^^ 주문후 다음날...
# 8      주문하고 바로 설치안내문자오더니 토요일에 기사님 오셔서 설치해주셨어요 싸게 잘 샀습니다
# 9                                너무 예뻐요 배송 잘 해주셔서 고맙습니다
# 10                                     충전이 번거롭긴 하지만 대만족
# 11    친절하게 설치해주시구 무었보다 빠르게 설치해주셔서 넘 좋았어요 >__< 좋은가격에 ...
# 12                                     이동하기 너무 편해서 좋네요.
# 13      배송 이틀만에 왔구요 와서 조립까지 다 해주고 가셨어요!저렴한 가격에 적극 추천합니다
# 14          너무 좋아요무겁지만 바퀴가 있어 이동이 용이 하고사운드,화질등 나무랄게 없어요
# 15                    밥 먹을때 자기전에 이동하면서 보고있는데 너무 편하고 좋아요
# 16                             lg기사님들도 친절하시고 tv도 좋아요!!!
# 17                                 상품에 만족하여 잘 사용하고 있습니다
# 18                                      신속한 설치..설명 잘햇어여
# 19                                  좋아요좋아요좋아요 좋아요좋아요좋아요
# Name: 내용, dtype: object

# %%
# 응답들을 저장할 리스트
content_list = []

total_iterations = len(test)

with tqdm(total=total_iterations) as pbar:
    for i, text in enumerate(test):

        # (Step 1) 각 raw_text에 대해 issue와 sentiment 추출
        input_raw_text = text
        system_message = {"role": "system", "content": sentiment_instructions}
        user_message = {"role": "user", "content": f"{sentiment_few_shots}\n<raw_text>\n{input_raw_text}\n</raw_text>"}
        messages = [system_message, user_message]

        # GPT-4로부터 응답 받기
        content = get_response(messages)
        if not content:
            pbar.update(1)
            time.sleep(1)
            continue
        
        # 응답을 리스트에 저장
        content_list.append(content)
        
        pbar.update(1)
        time.sleep(1)

# content_list를 DataFrame으로 변환
# Out:
# 100%|██████████| 20/20 [00:51<00:00,  2.59s/it]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 29
#      26         time.sleep(1)
#      28 # content_list를 DataFrame으로 변환
# ---> 29 df = convert_to_dataframe([content_list])
#
# Cell In[38], line 55, in convert_to_dataframe(content_list)
#      52 if not content:
#      53     continue  # content가 None이거나 비어 있을 때 건너뜀
# ---> 55 content_dict = convert_to_dict(content)
#      56 if not content_dict:
#      57     continue  # JSON 변환에 실패한 경우 건너뜀
#
# Cell In[38], line 40, in convert_to_dict(content)
#      38 def convert_to_dict(content):
#      39     try:
# ---> 40         return json.loads(content)
#      41     except json.JSONDecodeError as e:
#      42         print(f"Error decoding JSON: {e}")
#
# File ~/.pyenv/versions/3.10.13/lib/python3.10/json/__init__.py:339, in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     337 else:
#     338     if not isinstance(s, (bytes, bytearray)):
# --> 339         raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     340                         f'not {s.__class__.__name__}')
#     341     s = s.decode(detect_encoding(s), 'surrogatepass')
#     343 if (cls is None and object_hook is None and
#     344         parse_int is None and parse_float is None and
#     345         parse_constant is None and object_pairs_hook is None and not kw):
#
# TypeError: the JSON object must be str, bytes or bytearray, not list

# %%
content_list
# Out:
# ['{\n  "raw_text": "조아용 조아용 조아용 ㅎㅎ",\n  "issue": [\n    "만족"\n  ],\n  "sentiment": {\n    "만족": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "너무 만족하며 사용중입니다",\n  "issue": [\n    "사용 만족"\n  ],\n  "sentiment": {\n    "사용 만족": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요",\n  "issue": [\n    "빠른 설치 및 배송",\n    "설치 서비스 만족"\n  ],\n  "sentiment": {\n    "빠른 설치 및 배송": "긍정",\n    "설치 서비스 만족": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요",\n  "issue": [\n    "여자친구 만족",\n    "선물로 추천"\n  ],\n  "sentiment": {\n    "여자친구 만족": "긍정",\n    "선물로 추천": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "살까말까 했는데 좋아요",\n  "issue": [\n    "좋은 제품"\n  ],\n  "sentiment": {\n    "좋은 제품": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "빠른 배송 감사합니다. LG에서 직잡 배송/설치 했습니다. .",\n  "issue": [\n    "빠른 배송",\n    "직접 배송/설치"\n  ],\n  "sentiment": {\n    "빠른 배송": "긍정",\n    "직접 배송/설치": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "자취하는데 뭔 티비야 .. 하면서 노트북이나 패드로 유튜브, ott 시청했었는데 확실히 더 큰 화면으로 보니까 너무 조아요설거지하거나 가구 배치 바꿀 때도 쉽게 움직여서 이동시킬 수 있으니까 정말 좋습니다..삶의 질이 향상됐어요 ㅎㅎ",\n  "issue": [\n    "더 큰 화면으로 OTT 시청 좋음",\n    "이동 편리"\n  ],\n  "sentiment": {\n    "더 큰 화면으로 OTT 시청 좋음": "긍정",\n    "이동 편리": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "핸드폰으로 ott를 보다보니 항상 아쉬웠는데 고민고민하다질렀어요~^^ 주문후 다음날 오전에 배송설치했고 생각한대로 디자인이나 품질 맘에들어요",\n  "issue": [\n    "OTT 시청",\n    "빠른 배송",\n    "디자인 만족",\n    "품질 만족"\n  ],\n  "sentiment": {\n    "OTT 시청": "중립",\n    "빠른 배송": "긍정",\n    "디자인 만족": "긍정",\n    "품질 만족": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "주문하고 바로 설치안내문자오더니 토요일에 기사님 오셔서 설치해주셨어요 싸게 잘 샀습니다",\n  "issue": [\n    "빠른 설치 안내",\n    "설치 만족",\n    "저렴한 가격"\n  ],\n  "sentiment": {\n    "빠른 설치 안내": "긍정",\n    "설치 만족": "긍정",\n    "저렴한 가격": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "너무 예뻐요 배송 잘 해주셔서 고맙습니다",\n  "issue": [\n    "예쁜 디자인",\n    "배송 만족"\n  ],\n  "sentiment": {\n    "예쁜 디자인": "긍정",\n    "배송 만족": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "충전이 번거롭긴 하지만 대만족",\n  "issue": [\n    "충전 번거로움",\n    "대만족"\n  ],\n  "sentiment": {\n    "충전 번거로움": "부정",\n    "대만족": "긍정"\n  },\n  "sentiment_all": "중립"\n}',
#  '{\n  "raw_text": "친절하게 설치해주시구 무었보다 빠르게 설치해주셔서 넘 좋았어요 >__< 좋은가격에 좋은서비스 최고입니다!",\n  "issue": [\n    "친절한 설치",\n    "빠른 설치",\n    "좋은 가격",\n    "좋은 서비스"\n  ],\n  "sentiment": {\n    "친절한 설치": "긍정",\n    "빠른 설치": "긍정",\n    "좋은 가격": "긍정",\n    "좋은 서비스": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "이동하기 너무 편해서 좋네요.",\n  "issue": [\n    "이동 편리"\n  ],\n  "sentiment": {\n    "이동 편리": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "배송 이틀만에 왔구요 와서 조립까지 다 해주고 가셨어요!저렴한 가격에 적극 추천합니다",\n  "issue": [\n    "빠른 배송",\n    "조립 서비스",\n    "저렴한 가격",\n    "적극 추천"\n  ],\n  "sentiment": {\n    "빠른 배송": "긍정",\n    "조립 서비스": "긍정",\n    "저렴한 가격": "긍정",\n    "적극 추천": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "너무 좋아요무겁지만 바퀴가 있어 이동이 용이 하고사운드,화질등 나무랄게 없어요",\n  "issue": [\n    "무겁지만 이동 용이",\n    "우수한 사운드",\n    "우수한 화질"\n  ],\n  "sentiment": {\n    "무겁지만 이동 용이": "중립",\n    "우수한 사운드": "긍정",\n    "우수한 화질": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "밥 먹을때 자기전에 이동하면서 보고있는데 너무 편하고 좋아요",\n  "issue": [\n    "이동 편리",\n    "식사시간 시청",\n    "자기전 시청"\n  ],\n  "sentiment": {\n    "이동 편리": "긍정",\n    "식사시간 시청": "중립",\n    "자기전 시청": "중립"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "lg기사님들도 친절하시고 tv도 좋아요!!!",\n  "issue": [\n    "친절한 기사님",\n    "좋은 TV"\n  ],\n  "sentiment": {\n    "친절한 기사님": "긍정",\n    "좋은 TV": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "상품에 만족하여 잘 사용하고 있습니다",\n  "issue": [\n    "제품 만족"\n  ],\n  "sentiment": {\n    "제품 만족": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "신속한 설치..설명 잘햇어여",\n  "issue": [\n    "신속한 설치",\n    "설명 만족"\n  ],\n  "sentiment": {\n    "신속한 설치": "긍정",\n    "설명 만족": "긍정"\n  },\n  "sentiment_all": "긍정"\n}',
#  '{\n  "raw_text": "좋아요좋아요좋아요 좋아요좋아요좋아요",\n  "issue": [\n    "좋은 제품"\n  ],\n  "sentiment": {\n    "좋은 제품": "긍정"\n  },\n  "sentiment_all": "긍정"\n}']

# %%
data_list = []

for content in content_list:
    parsed_content = convert_to_dict(content)

    raw_text = extract_raw_text(parsed_content)
    issues = extract_issues(parsed_content)
    sentiments = extract_sentiments(parsed_content)
    sentiment_all = extract_sentiment_all(parsed_content)

    for issue in issues:
        sentiment = sentiments.get(issue, 'Unknown')
        data_entry = {
            "raw_text": raw_text,
            "issue": issue,
            "sentiment": sentiment,
            "sentiment_all": sentiment_all
        }
        data_list.append(data_entry)

result = pd.DataFrame(data_list)
result
# Out:
#                                              raw_text               issue  \
# 0                                      조아용 조아용 조아용 ㅎㅎ                  만족
# 1                                      너무 만족하며 사용중입니다               사용 만족
# 2       4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요          빠른 설치 및 배송
# 3       4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요           설치 서비스 만족
# 4                        여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요             여자친구 만족
# 5                        여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요              선물로 추천
# 6                                        살까말까 했는데 좋아요               좋은 제품
# 7                  빠른 배송 감사합니다. LG에서 직잡 배송/설치 했습니다. .               빠른 배송
# 8                  빠른 배송 감사합니다. LG에서 직잡 배송/설치 했습니다. .            직접 배송/설치
# 9   자취하는데 뭔 티비야 .. 하면서 노트북이나 패드로 유튜브, ott 시청했었는데 확...  더 큰 화면으로 OTT 시청 좋음
# 10  자취하는데 뭔 티비야 .. 하면서 노트북이나 패드로 유튜브, ott 시청했었는데 확...               이동 편리
# 11  핸드폰으로 ott를 보다보니 항상 아쉬웠는데 고민고민하다질렀어요~^^ 주문후 다음날...              OTT 시청
# 12  핸드폰으로 ott를 보다보니 항상 아쉬웠는데 고민고민하다질렀어요~^^ 주문후 다음날...               빠른 배송
# 13  핸드폰으로 ott를 보다보니 항상 아쉬웠는데 고민고민하다질렀어요~^^ 주문후 다음날...              디자인 만족
# 14  핸드폰으로 ott를 보다보니 항상 아쉬웠는데 고민고민하다질렀어요~^^ 주문후 다음날...               품질 만족
# 15   주문하고 바로 설치안내문자오더니 토요일에 기사님 오셔서 설치해주셨어요 싸게 잘 샀습니다            빠른 설치 안내
# 16   주문하고 바로 설치안내문자오더니 토요일에 기사님 오셔서 설치해주셨어요 싸게 잘 샀습니다               설치 만족
# 17   주문하고 바로 설치안내문자오더니 토요일에 기사님 오셔서 설치해주셨어요 싸게 잘 샀습니다              저렴한 가격
# 18                             너무 예뻐요 배송 잘 해주셔서 고맙습니다              예쁜 디자인
# 19                             너무 예뻐요 배송 잘 해주셔서 고맙습니다               배송 만족
# 20                                   충전이 번거롭긴 하지만 대만족             충전 번거로움
# 21                                   충전이 번거롭긴 하지만 대만족                 대만족
# 22  친절하게 설치해주시구 무었보다 빠르게 설치해주셔서 넘 좋았어요 >__< 좋은가격에 ...              친절한 설치
# 23  친절하게 설치해주시구 무었보다 빠르게 설치해주셔서 넘 좋았어요 >__< 좋은가격에 ...               빠른 설치
# 24  친절하게 설치해주시구 무었보다 빠르게 설치해주셔서 넘 좋았어요 >__< 좋은가격에 ...               좋은 가격
# 25  친절하게 설치해주시구 무었보다 빠르게 설치해주셔서 넘 좋았어요 >__< 좋은가격에 ...              좋은 서비스
# 26                                   이동하기 너무 편해서 좋네요.               이동 편리
# 27    배송 이틀만에 왔구요 와서 조립까지 다 해주고 가셨어요!저렴한 가격에 적극 추천합니다               빠른 배송
# 28    배송 이틀만에 왔구요 와서 조립까지 다 해주고 가셨어요!저렴한 가격에 적극 추천합니다              조립 서비스
# 29    배송 이틀만에 왔구요 와서 조립까지 다 해주고 가셨어요!저렴한 가격에 적극 추천합니다              저렴한 가격
# 30    배송 이틀만에 왔구요 와서 조립까지 다 해주고 가셨어요!저렴한 가격에 적극 추천합니다               적극 추천
# 31        너무 좋아요무겁지만 바퀴가 있어 이동이 용이 하고사운드,화질등 나무랄게 없어요          무겁지만 이동 용이
# 32        너무 좋아요무겁지만 바퀴가 있어 이동이 용이 하고사운드,화질등 나무랄게 없어요             우수한 사운드
# 33        너무 좋아요무겁지만 바퀴가 있어 이동이 용이 하고사운드,화질등 나무랄게 없어요              우수한 화질
# 34                  밥 먹을때 자기전에 이동하면서 보고있는데 너무 편하고 좋아요               이동 편리
# 35                  밥 먹을때 자기전에 이동하면서 보고있는데 너무 편하고 좋아요             식사시간 시청
# 36                  밥 먹을때 자기전에 이동하면서 보고있는데 너무 편하고 좋아요              자기전 시청
# 37                           lg기사님들도 친절하시고 tv도 좋아요!!!             친절한 기사님
# 38                           lg기사님들도 친절하시고 tv도 좋아요!!!               좋은 TV
# 39                               상품에 만족하여 잘 사용하고 있습니다               제품 만족
# 40                                    신속한 설치..설명 잘햇어여              신속한 설치
# 41                                    신속한 설치..설명 잘햇어여               설명 만족
# 42                                좋아요좋아요좋아요 좋아요좋아요좋아요               좋은 제품
#
#    sentiment sentiment_all
# 0         긍정            긍정
# 1         긍정            긍정
# 2         긍정            긍정
# 3         긍정            긍정
# 4         긍정            긍정
# 5         긍정            긍정
# 6         긍정            긍정
# 7         긍정            긍정
# 8         긍정            긍정
# 9         긍정            긍정
# 10        긍정            긍정
# 11        중립            긍정
# 12        긍정            긍정
# 13        긍정            긍정
# 14        긍정            긍정
# 15        긍정            긍정
# 16        긍정            긍정
# 17        긍정            긍정
# 18        긍정            긍정
# 19        긍정            긍정
# 20        부정            중립
# 21        긍정            중립
# 22        긍정            긍정
# 23        긍정            긍정
# 24        긍정            긍정
# 25        긍정            긍정
# 26        긍정            긍정
# 27        긍정            긍정
# 28        긍정            긍정
# 29        긍정            긍정
# 30        긍정            긍정
# 31        중립            긍정
# 32        긍정            긍정
# 33        긍정            긍정
# 34        긍정            긍정
# 35        중립            긍정
# 36        중립            긍정
# 37        긍정            긍정
# 38        긍정            긍정
# 39        긍정            긍정
# 40        긍정            긍정
# 41        긍정            긍정
# 42        긍정            긍정

# %% [markdown]
# # 적용 영역

# %%
df
# Out:
#                                                     내용            구매처  평점  \
# 0                                       조아용 조아용 조아용 ㅎㅎ        오아시스486   5
# 1                                       너무 만족하며 사용중입니다           Ader   5
# 2        4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요           Ader   5
# 3                         여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요           Ader   5
# 4                                         살까말까 했는데 좋아요           11번가   4
# ..                                                 ...            ...  ..
# 995                           선물용으로 구매했는데 빠른 배송 감사합니다.           LG전자   5
# 996                        사무실 휴대용으로 구매했습니다. 만족한것 같습니다  LG전자인증점 신영플러스   5
# 997  물건 잘 받았습니다 배송도 좋게 보내 주시고 제품도 좋고 조금 아쉬운 게 충전 충정...      알렛츠ALLETS   5
# 998  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...           오늘의집   5
# 999  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...           오늘의집   4
#
#           작성날짜       사용자      상품
# 0    24.05.15.  rorn****   스탠바이미
# 1    24.05.15.  arde****   스탠바이미
# 2    24.05.15.  jeon****   스탠바이미
# 3    24.05.15.  pjw9****   스탠바이미
# 4    24.05.15.  m0******   스탠바이미
# ..         ...       ...     ...
# 995  23.09.06.  c*0*****  스탠바이미고
# 996  23.09.06.  fore****  스탠바이미고
# 997  23.09.05.  gilg****  스탠바이미고
# 998  23.09.05.  1*6*****  스탠바이미고
# 999  23.09.05.  9*2*****  스탠바이미고
#
# [1000 rows x 6 columns]

# %% [markdown]
# ### Step 1) gpt api 호출

# %%
text_apply = df['내용']

# %%
# 응답들을 저장할 리스트
content_list = []

total_iterations = len(text_apply)

with tqdm(total=total_iterations) as pbar:
    for i, text in enumerate(text_apply):

        # (Step 1) 각 raw_text에 대해 issue와 sentiment 추출
        input_raw_text = text
        system_message = {"role": "system", "content": sentiment_instructions}
        user_message = {"role": "user", "content": f"{sentiment_few_shots}\n<raw_text>\n{input_raw_text}\n</raw_text>"}
        messages = [system_message, user_message]

        # GPT-4로부터 응답 받기
        content = get_response(messages)
        if not content:
            pbar.update(1)
            time.sleep(1)
            continue
        
        # 응답을 리스트에 저장
        content_list.append(content)
        
        pbar.update(1)
        time.sleep(1)
# Out:
# 100%|██████████| 1000/1000 [44:43<00:00,  2.68s/it]

# %% [markdown]
# ### Step 2) 답변 dataframe 변환

# %%
# 답변 변환

data_list = []

for content in content_list:
    parsed_content = convert_to_dict(content)

    raw_text = extract_raw_text(parsed_content)
    issues = extract_issues(parsed_content)
    sentiments = extract_sentiments(parsed_content)
    sentiment_all = extract_sentiment_all(parsed_content)

    for issue in issues:
        sentiment = sentiments.get(issue, 'Unknown')
        data_entry = {
            "raw_text": raw_text,
            "issue": issue,
            "sentiment": sentiment,
            "sentiment_all": sentiment_all
        }
        data_list.append(data_entry)

result = pd.DataFrame(data_list)
result
# Out:
#                                                raw_text       issue sentiment  \
# 0                                        조아용 조아용 조아용 ㅎㅎ       좋은 제품        긍정
# 1                                        너무 만족하며 사용중입니다          만족        긍정
# 2         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요    빠른 설치 배송        긍정
# 3         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요   설치 서비스 만족        긍정
# 4                          여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요     여자친구 만족        긍정
# ...                                                 ...         ...       ...
# 2468  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...    야외 사용 기대        긍정
# 2469  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...        대대만족        긍정
# 2470  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...  아늑한 영화관 느낌        긍정
# 2471  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...       이동 편리        긍정
# 2472  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...     캠핑에서 유용        긍정
#
#      sentiment_all
# 0               긍정
# 1               긍정
# 2               긍정
# 3               긍정
# 4               긍정
# ...            ...
# 2468            긍정
# 2469            긍정
# 2470            긍정
# 2471            긍정
# 2472            긍정
#
# [2473 rows x 4 columns]

# %% [markdown]
# ### Step3) theme 생성(군집분석)

# %%
# issue에서 중복 제거
unique_issues = result['issue'].drop_duplicates().tolist()

# %%
len(unique_issues)
# Out:
# 1153

# %%
def classify_issues(issues):
    # 'instructions'는 모델의 행동 방침을 설정하므로 system 메시지에 포함
    messages = [
        {"role": "system", "content": theme_instructions},
        {"role": "user", "content": f"다음 이슈들을 의미적으로 비슷한 그룹으로 나누고, 각 그룹의 공통 테마를 도출해줘: {issues}"},
        {"role": "user", "content": f"예시: {theme_few_shots}"}
    ]
    
    return get_response(messages)

# %% [markdown]
# ### batch50

# %%
# 유니크한 이슈들을 GPT API로 분류
themes = []
batch_size = 50  # 한번에 너무 많은 데이터를 보내지 않기 위해 배치 처리
for i in range(0, len(unique_issues), batch_size):
    batch_issues = unique_issues[i:i+batch_size]
    themes.append(classify_issues(', '.join(batch_issues)))

# 배치 결과를 합쳐서 하나의 테마 리스트로 변환
theme_list = [theme.strip() for theme in ', '.join(themes).split(',')]

# %%
themes
# Out:
# ['{\n  "제품 품질 및 성능": ["좋은 제품", "우수한 사운드", "우수한 화질", "좋은 TV", "품질 만족"],\n  "설치 및 배송 서비스": ["빠른 설치 배송", "설치 서비스 만족", "직접 배송 및 설치", "친절한 설치", "신속한 설치", "배송 설치", "친절한 배송", "친절한 설치 기사", "친절한 기사", "빠른 설치 안내", "조립 서비스"],\n  "가격 및 혜택": ["저렴한 가격", "좋은 가격", "할인"],\n  "사용자 만족도": ["만족", "여자친구 만족", "대만족", "제품 만족", "만족스러운 소비", "추천", "적극 추천", "부모님 선물 추천", "TV 미시청자 추천"],\n  "디자인 및 외관": ["디자인 만족", "예쁜 디자인"],\n  "편리성 및 사용성": ["이동 편리", "무겁지만 이동 용이", "편리한 터치", "터치 작동", "누워서 사용하기 좋음"],\n  "콘텐츠 시청 경험": ["더 큰 화면으로 OTT 시청 좋음", "OTT 시청", "OTT/유튜브 시청 좋음", "식사시간 시청", "자기전 시청"],\n  "서비스 및 고객 응대": ["좋은 서비스", "친절한 서비스"],\n  "기타": ["선물 아쉬움", "충전 번거로움", "리모컨", "빠른 구매", "설명 만족"]\n}',
#  '{\n  "디자인 및 인테리어": ["훌륭한 디자인", "깔끔한 디자인", "인테리어와 조화", "뒷면 색상"],\n  "화질 및 음향": ["만족스러운 화질", "좋은 화질", "깨끗한 화면", "만족스러운 음량", "좋은 소리"],\n  "설치 및 이동": ["편리한 이동", "이동성", "조용한 이동", "섬세한 설치", "설치 만족", "이동식 티비 만족"],\n  "사용 편의성": ["실용성", "편리한 사용", "다양한 기기 사용", "OTT 시청 편리", "넷플릭스 시청", "TV없는 가정에서 유용", "지상파 미시청", "유료 어플 필요", "TV 시청 가능", "전용티비", "아이들 교육에 유용", "운동 시 사용", "좁은 방에서 스피커 불필요", "거실 시청", "안방 시청", "좁은 공간에서 활용 좋음"],\n  "구매 및 배송": ["안전한 배송", "배송 시간 지정 가능", "친절한 판매자", "친절한 설치기사", "구매 만족", "만족스러운 구매", "가격 만족", "적기에 상품 구입"],\n  "추천 및 만족도": ["강추", "추천 의사", "선물로 좋음", "가치 있음", "잘 사용 중", "구입 망설임", "티비와 다름", "큰 화면으로 시청", "만족스러운 구매"],\n  "내구성": ["내구성", "튼튼한 기둥"]\n}',
#  '{\n  "화면 및 디자인 만족": ["편리한 화면 조절", "큰 화면", "평범한 화질", "이쁜 디자인", "디자인 예쁨", "심플한 디자인"],\n  "사용 만족 및 편리성": ["사용 만족", "스탠바이미 만족", "좋음", "편리함", "운동 시 사용 편리", "작동 만족", "간편함", "집에서 사용 적합", "안방에서 높은 활용도", "무선 사용 가능", "전반적 만족", "신세계 경험", "진작 구매 후회", "최고의 제품", "제품 사용 만족"],\n  "배송 및 설치 서비스": ["빠른 배송 및 설치", "친절한 배송 기사", "친절한 설치 서비스", "우수한 설치 서비스", "정확한 배송", "배송 일정 조율 가능", "희망 배송일 맞춤", "사전 연락", "깔끔한 설치"],\n  "제품 품질 및 기대": ["깨끗하고 예쁜 제품", "다양한 활용", "최고의 선택", "제품 기대", "제품 퀄리티", "만족스러운 제품"],\n  "가격 및 구매 경험": ["좋은 구매 기회", "가격 가치", "비싼 가격", "구매 욕구"],\n  "미디어 및 사운드": ["아기 미디어 노출 방지", "좋은 사운드", "OTT/유튜브 사용 추천", "작업 중 음악 듣기"],\n  "부정적 피드백": ["배송 지연", "배송 실수", "전원어댑터 일체화 아쉬움", "느린 웹서핑"]\n}',
#  '{\n  "디자인 및 마감": ["좋은 디자인", "깔끔한 마감", "인테리어 효과"],\n  "음질 및 스피커": ["좋은 음질", "괜찮은 스피커", "스피커 답답함"],\n  "크기 및 무게": ["적절한 크기", "화면 크기 아쉬움", "가벼운 무게"],\n  "사용 편의성": ["터치 스크린", "사용 편리", "직관적인 사용 방법", "터치 기능", "무난한 사용"],\n  "배송 및 설치": ["원하는 날짜에 배송 설치", "직접 조립 서비스", "친절한 설치 및 사용 설명"],\n  "화질 및 성능": ["괜찮은 화질", "우수한 성능", "성능 만족", "성능 평가 미정", "가격 대비 성능"],\n  "가격": ["비쌈", "높은 가격", "가격 대비 좋음", "착한 가격", "가격 비교"],\n  "특별한 선물": ["임신 선물 만족", "생일선물 서프라이즈 성공", "생일 선물"],\n  "일상 사용": ["매일 사용", "방에서 시청", "실시간 TV 가능", "넷플릭스 시청 만족", "영화 시청", "침대에서 사용", "방에서 TV 시청 가능", "정자세로 시청 가능"],\n  "부가 기능": ["HDMI 케이블 제공", "듀얼모니터 사용", "움직이는 27인치 태블릿", "부드러운 바퀴"],\n  "사용자 만족": ["삶의 질 상승", "늦은 구매 후회", "TV 없는 분들 추천", "아이가 좋아함", "아이의 핸드폰 사용 대체", "좋은 상품", "설명 잘해줌"]\n}',
#  '{\n  "사용 편의성": ["운동 영상 시청", "간단한 세팅과 안내", "여자친구가 잘 사용", "유용함", "편리한 시청", "숙소에서 편리한 사용", "컴팩트함", "방에서 필요시에만 시청", "스마트폰 시청 어려움", "강연/유튜브/네이버 뉴스 시청", "OTT/유튜브 시청", "가족과 다른 콘텐츠 시청", "서브 용도로 구매", "잘 작동함", "영화 및 자녀 교육용 사용 만족"],\n  "배송 및 설치 서비스": ["재고 확인 및 배송 일정 체크", "안전한 배송 및 설치", "좋은 배송", "친절한 배송기사", "설치 서비스", "늦은 배송", "배송 문제"],\n  "제품 만족도 및 추천": ["LG 제품 만족", "고민 후 구매", "후회 없는 구매", "구입 만족", "만족스러운 상품", "만족스러운 사용", "부모님댁 설치 만족"],\n  "라이프스타일 및 활용": ["집순이에게 필수템", "신혼 선물로 적합", "삶의 질 향상", "라이프 스타일 변화", "미라클모닝 활용", "TV 없는 집에서 유용"],\n  "기능 및 디자인": ["화면 크기 적당", "터치스크린 선택", "터치의 이점", "무선의 이점", "충전 가능", "깨끗한 화질", "아름다운 디자인", "귀여운 디자인"],\n  "문제 및 불만": ["판매처 문제", "사기 의심", "장판에 사람모양 새겨짐"],\n  "가격 및 행사": ["가격 하락", "행사에서 렌탈 활용"]\n}',
#  '{\n  "사용 만족도": ["만족스러움", "재구매 의향", "생활의 질 향상", "좋은 사용 경험", "만족도 최고", "전반적인 만족", "높은 완성도", "아이들 만족", "어머니 만족"],\n  "설치 및 서비스": ["쉬운 자가설치", "지정일 방문 설치", "만족스러운 설치 서비스", "좋은 설치", "기사님의 시간 확인 연락", "박스 수거", "친절한 상담"],\n  "가격 및 구매": ["저렴한 구매 방법 발견", "오프라인보다 저렴한 가격", "합리적인 가격", "저렴한 행사 가격"],\n  "제품 추천 및 활용": ["OTT 시청 추천", "구입 추천", "아이 학습용", "티비 대용", "높은 활용도", "침대에서 TV 시청", "원룸에서 적합한 사이즈", "식탁에서 보드 게임 사용", "식사 중 음악 사용"],\n  "제품 성능 및 기능": ["반응 속도 개선", "좋은 기능", "긴 배터리 지속 시간", "좋은 이동성", "자세한 기능 설명"],\n  "부정적 경험": ["휴대폰 사용 감소", "TV 미시청", "허위 광고", "무료배송 및 설치 불이행", "리뷰 조작 의심", "고객센터 및 판매자 대응 불만", "빠른 방전", "작은 화면", "아쉬운 화질 및 음향", "최대 높이 낮음"],\n  "배송 및 상태": ["주문 후 배송 시간", "제품 상태 양호", "직접 배달"],\n  "상품 가치": ["상품 가치와 퀄리티", "거실 분위기 변화"]\n}',
#  '{\n  "사용 편리성": ["무선 편리", "간편한 사용", "높은 사용만족도", "탁월한 선택", "구매 추천", "친절한 설치 및 설명", "빠른 배달 및 설치", "신속 설치", "부드러운 이동", "편리성", "이동 가능", "끊김없는 영상 시청", "홈트 편리", "영화 보기 만족", "적당한 크기", "다양한 쓰임", "스탠바이미 원조", "게임 가능"],\n  "화면 및 시청 경험": ["화면 터치", "큰 TV 대체", "TV없는 신혼집에서 유용", "누워서 시청", "요리하면서 시청", "큰 태블릿 같음"],\n  "사용 환경 및 상황": ["침대에서 각도 불편", "높은 침대에서 편리", "눈높이 및 각도 조절 용이", "침실에서 사용 좋음", "유선 TV 연결 어려움"],\n  "소음 및 연결 문제": ["소음 문제", "느린 인터넷", "유선 TV 연결 어려움"],\n  "디자인 및 인테리어": ["예쁜 인테리어", "인테리어 용도"],\n  "가격 및 품질": ["합리적 가격", "가격대비 최고의 품질", "좋은 구매 조건"],\n  "선물 및 추천": ["딸 선물 만족", "부모님 선물", "친구들과 사용 좋음", "개인 사용 좋음", "가족과 함께 사용"],\n  "배송 및 설치 서비스": ["빠른 배달 및 설치", "신속 정확한 배송", "친절한 설치 및 설명"],\n  "제품 만족도": ["높은 사용만족도", "좋은 사용감", "좋은 물건", "상품 문제 없음", "다른 부분 만족", "혁명적 제품"],\n  "구매 고려": ["구입 고민"]\n}',
#  '{\n  "시청 경험": ["유튜브 및 넷플릭스 시청", "영상 시청용", "아이들 유튜브 시청", "침대에서 편리한 시청", "큰 화면으로 시청 좋음", "TV 보기 간편", "부모님 사용 만족", "TV 없는 환경에서 추천"],\n  "제품 만족도": ["처음에는 기대보다 실망", "전체적으로 만족", "완전 만족", "상품 만족", "기대 이상", "가족 만족", "좋은 구매", "아주 좋음", "최고의 가전제품 구매"],\n  "설치 및 사용 편의성": ["티비로 인한 싸움 해결", "티비 사용 빈도 증가", "쉬운 작동", "스마트 TV로 교체", "이동 용이", "설치 빠름", "꼼꼼한 설치", "대체공휴일 설치"],\n  "연결 및 네트워크 문제": ["와이파이 문제", "엘지띵큐앱 기기 연결 문제", "공유기 문제 해결"],\n  "고객 서비스 및 배송": ["빠른 주문", "친절한 설명", "빠른 답변", "감사", "잘 사용", "반품 경험", "새상품 수령", "직접 배송", "배송 속도"],\n  "제품 디자인 및 부가 기능": ["카메라 거치대 미포함 아쉬움", "이쁜 인테리어", "디자인"],\n  "기타": ["사용할수록 편리", "배터리 지속 시간", "무거움", "선물로 적합", "유용성", "하자 없는 제품", "기스난 상품", "재구매"]\n}',
#  '{\n  "화질 및 시청 경험": ["화질", "또렷한 화면", "큰 화면으로 영상 시청", "눈이 편함", "OTT 시청의 질 향상"],\n  "제품 설치 및 배송": ["완벽한 설치", "정확한 설치 날짜", "지정일 배송", "배송업체와 협의 필요", "공급부족으로 인한 배송 지연", "깔끔한 배송 및 설치"],\n  "이동 및 활용성": ["누워서 TV 시청", "거실과 안방 이동", "충전 및 이동 편리", "이동형 티비", "이동 시청 가능", "설거지할 때 시청", "자기 전 시청"],\n  "구매 및 신뢰성": ["OTT 상품 결제", "공식인증점 구매 신뢰", "오리지널 제품 선호", "신제품 구매 추천", "구매대행", "좋은 가격에 구매"],\n  "다양한 사용 환경": ["미러링 기능", "파티 활용", "스포츠 게임 가능", "유튜브 강의 시청", "드라마 정주행", "닌텐도 사용 가능"],\n  "제품 상태 및 만족도": ["상품 상태 좋음", "잘 구입했다는 느낌", "명품가전", "좋은 반응속도", "최애 상품", "새로운 경험"],\n  "추천 및 선호": ["필수품", "자취생 추천", "결혼 선물로 적합", "집순이/집돌이 추천"],\n  "경제성": ["가성비 좋음", "편리한 활용도", "공간 절약"],\n  "기타": ["스피커 품절 아쉬움", "리모컨 조작 가능", "무선 이용 가능", "아이패드와 비교"]\n}',
#  '{\n  "고객 만족도": ["딸의 만족", "매우 만족", "높은 만족도", "최고의 구매", "감사 인사", "제품 사용 의향", "긴 배송 시간", "오래 걸리는 배송", "대기 시간"],\n  "제품 디자인 및 인테리어": ["우수한 디자인", "인테리어 소품으로 좋음", "집에 잘 어울림", "완벽한 사이즈", "티비와 다른 느낌"],\n  "배송 및 설치 서비스": ["설치비 포함", "안전한 배달", "배송 어려움", "원하는 날짜에 배송", "친절한 기사님", "좋은 설치 서비스", "무료배송", "지정배송"],\n  "가격 및 인기": ["가격 인상", "가격", "상품 인기", "인기 상품"],\n  "제품 사용성": ["가정에서 사용 좋음", "티비 없는 거실에 적합", "좋은 음량", "영화관 같은 경험", "아이의 집중", "간단한 시청", "세컨 TV로 사용", "태블릿으로 사용", "영상용으로 적합", "국민템", "사용 편안", "다양한 기능", "침대에서 시청", "1인 가구 추천", "하루 종일 시청", "쉬운 미러링", "쉬운 스마트뷰 연결"],\n  "선물 및 추천": ["집들이 선물", "직원 선물 준비"],\n  "품질 및 성능": ["좋은 품질", "기대 이하의 화질", "짧은 무선 사용 시간"],\n  "판매자 소통": ["판매자의 소통 부족"]\n}',
#  '{\n  "제품 만족도": ["스피커 추가 구매로 만족도 상승", "우수한 스피커", "선물로 만족", "거실에서 시청 만족", "캠핑장에서 만족", "캠핑에서 사용 만족", "TV없는 생활에서 스탠바이미 만족", "예상만큼 좋은 품질", "최고의 안방 TV"],\n  "설치 및 배송 서비스": ["정확한 설치일", "신속, 정확, 친절", "직배송", "설치 및 설명", "친절한 설치 및 배송", "배송 날짜 지정", "깨끗한 설치"],\n  "사용 편의성": ["자유로운 사용", "휴대폰 미러링", "큰 화면으로 유튜브/넷플릭스 시청", "공간별 이동 용이", "방에서 사용 좋음", "행사용으로 적합", "다양한 활용 가능", "터치 기능 사용 빈도 낮음", "감성적인 디자인", "세심한 화면 구성", "편안한 메뉴 구성"],\n  "가격 및 구매 조건": ["무이자 36개월", "저렴", "할인 구매", "행사 구매", "충동구매"],\n  "공간 활용": ["공간 활용", "TV 없는 거실에 적합", "인테리어 해치지 않음", "캠핑장에서 사용", "가정에서 활용", "캠핑에서 사용"],\n  "기타": ["좋은 구매 결정", "이즈베스트 업체 만족", "설명 제공", "인터넷 설치 기대", "OTT 서비스 다양", "가까운 거리에서 화질 저하", "무게감 있음", "체스 놀이", "분위기 조성", "낭랑한 사운드"]\n}',
#  '{\n  "품질 및 성능 만족": ["우수한 품질", "흠잡을 데 없는 화질", "흠잡을 데 없는 사운드", "흠잡을 데 없는 디자인", "좋아 보임", "큰 화면 만족", "좋은 연결성", "괜찮은 사용성", "흐린 화질", "보통의 화질", "큰 일반 TV 사운드", "작은 Apple Music 사운드", "스피커 업그레이드", "튼튼함", "튼튼한 제작"],\n  "이동성과 휴대성": ["이동식 사용 계획", "무겁지만 이동 가능", "이동 시 파손 위험 없음", "캠핑용 구매", "캠핑에서 잘 사용", "캠핑 및 가정에서 사용", "캠핑 및 외출 시 편리", "이동 중 사용", "야외용 활용도", "TV 없는 가정에서 유용", "블루투스 스피커 역할"],\n  "사용 경험 및 만족": ["서비스 만족", "힐링 경험", "영화 감상 편리", "음악 감상 좋음", "영화 감상 만족", "가족 게임 가능", "캠핑장에서 게임", "내장 게임", "구매 후 만족", "캠핑에서 만족", "활용도 좋음", "필수템"],\n  "가격 및 부가 혜택": ["가격 아쉬움", "가성비 만족", "포토리뷰 포인트 제공", "라이브 추가할인", "가방케이스 쿠폰 아쉬움"],\n  "제품 구성 및 기능": ["기능 미사용", "다양한 OTT 지원", "배터리 탑재", "풀터치 스크린", "케이스 포함", "신선한 생산일자"]\n}',
#  '{\n  "캠핑 및 휴대성": ["캠핑에서 유용", "캠핑용 사용", "캠핑용으로 사용", "가족캠핑에서 편리", "캠핑 필수품", "아이 있는 캠핑러 필수템", "휴대성 좋음", "언제 어디서든 사용 가능", "충전 후 이동 가능"],\n  "음향 및 사운드": ["짱짱한 사운드", "좋은 음향", "훌륭한 스피커", "실내 음향기기 사용"],\n  "화질 및 영상": ["적당한 화질", "4K 영상 표현", "티비 대용 사용", "힐링 영상", "축구경기 시청 만족", "보기 편함", "TV 및 컴퓨터 기능", "빔프로젝터 대체"],\n  "구매 및 가격": ["빠른 구매 결정 필요", "할인된 가격", "공식 홈페이지 구매", "할인 소식", "가치 초과 만족"],\n  "제품 만족도": ["강력추천", "마음에 듦", "구매 후회 없음", "괜찮은 제품", "재밌고 귀여운 제품", "만족", "무겁지만 크고 좋음", "무선 사용 시간 만족", "다용도", "가정에서 만족", "가정에서 사용", "낚시 중 사용", "무선 사용 시간"],\n  "브랜드 및 서비스": ["LG 가전제품 구매", "LG 브랜드 신뢰", "친절한 답변", "안전 배송", "느린 배송"],\n  "배터리 및 무게": ["오래가는 배터리", "조금 무거움", "무겁지만 크고 좋음"],\n  "기능 및 편의성": ["터치 편리", "애플 에어드롭 기능", "아이들 자제력 도움"]\n}',
#  '{\n  "휴대성과 이동성": ["휴대성", "무게 걱정", "무선 이동 가능", "이동시 유용", "캠핑용으로 적합", "캠핑족 필수템", "캠핑용 유용", "차박 기대", "차박 사용", "차박에 적합", "캠핑에서 사용 좋음", "캠핑에서 사용 기대", "캠핑 및 침대에서 사용", "낚시 및 캠핑에서 사용", "바닥 생활에 적합", "다양한 장소에서 사용 가능"],\n  "화질과 성능": ["아쉬운 화질", "극강의 화질", "좋은 동영상 품질", "힐링영상의 높은 해상도", "빔프로젝터보다 우수함", "좋은 성능"],\n  "배터리와 전원": ["배터리 용량", "배터리 이해"],\n  "가격과 구매": ["가성비 좋은 제품", "저렴한 구매", "특가 구매"],\n  "배송과 서비스": ["친절한 배송사원", "빠르고 안전한 배송"],\n  "사용 편의성": ["상세한 설명", "편리한 터치스크린", "우수한 터치 반응 속도", "OTT 연동", "스텐바이미go 사용 가능"],\n  "음향과 스피커": ["좋은 스피커 성능", "큰 소리", "만족스러운 음질"],\n  "가정 내 사용": ["안방 사용", "아이방에서 사용", "집에서 활용도 높음"],\n  "제품 디자인과 내구성": ["좋은 케이스 만듬새", "흠집 없음", "엘피 감성 디자인"],\n  "게임과 엔터테인먼트": ["아이와 게임", "조카 만족", "아이들 게임 가능", "닌텐도 연결 가능"],\n  "기능 제한": ["성능 제한", "어플 부족"]\n}',
#  '{\n  "시청 관련 만족": ["무선 시청 가능", "가족 모두 만족", "축구 시청 만족", "어디서든 시청 가능", "영화보기 편리"],\n  "사운드 및 음질": ["만족스러운 사운드", "훌륭한 음질", "만족스러운 스피커", "개선된 사운드"],\n  "디자인 및 외관": ["아쉬운 외관 디자인", "독보적인 디자인", "크기 만족"],\n  "설치 및 사용 편의": ["설치 불필요", "간편한 조작", "편리한 설정"],\n  "배송 및 서비스": ["기사님 직접 배송", "3일 배송", "늦게 받은 것에 대한 후회"],\n  "기능 및 호환성": ["Go의 더 좋은 기능", "게임 기능", "타기기와 호환", "OTT 기본 설치"],\n  "휴대성 및 활용성": ["여러 장소에서 사용", "캠핑에서 편리한 사용", "캠핑에서 활용도 좋음", "좋은 휴대성", "캠핑용으로 만족"],\n  "제품 만족도": ["문제 없음", "기대만큼 좋은 제품", "금액대비 만족"],\n  "편의 및 기타": ["편안함", "유용한 사용", "좋은 편의성"],\n  "부정적 요소": ["구매후기 강요", "사진 업로드 문제", "구글스토어 지원 아쉬움"],\n  "특별한 행사 및 기원": ["무이자 행사", "행운과 부유함 기원"],\n  "부피 및 무게": ["부피 크고 무거움", "보관 용이성"],\n  "터치 및 조작": ["만족스러운 터치스크린", "터치스크린 만족"],\n  "가족 및 어린이": ["아이의 만족"],\n  "게임 및 콘텐츠": ["게임 추가 필요"],\n  "리모컨 관련": ["리모컨 만족", "충전기와 리모컨 내장"]\n}',
#  '{\n  "캠핑 관련": [\n    "캠핑에서 사용 계획",\n    "캠핑 필수템",\n    "캠핑 장비 간소화",\n    "텐트에서 사용",\n    "여유로운 캠핑",\n    "캠핑에서 명품급",\n    "캠핑 및 야외 사용 적합",\n    "캠핑용으로 최고",\n    "캠핑용 번거로움",\n    "캠핑장에서 사용 만족"\n  ],\n  "화질 및 음질": [\n    "큰 화면과 좋은 화질",\n    "괜찮은 음질",\n    "화질 아쉬움",\n    "화질 불만족",\n    "깨끗하고 선명한 화질"\n  ],\n  "디자인 및 브랜드 만족": [\n    "고급스러움",\n    "LG 브랜드 만족",\n    "고급스러운 디자인",\n    "유니크한 디자인",\n    "기존 LG 룸앤티비 만족"\n  ],\n  "사용 편의성": [\n    "편리한 리모콘",\n    "터치식 만족",\n    "보관 용이",\n    "편리한 터치 화면",\n    "편리한 가방",\n    "편리한 휴대",\n    "간편한 휴대성",\n    "이동 불편",\n    "스탠바이미고 이동 편리"\n  ],\n  "제품 크기 및 무게": [\n    "무겁지만 안정감",\n    "생각보다 큰 크기",\n    "크고 무거움",\n    "이동 불편"\n  ],\n  "기타": [\n    "집순이에게 적합",\n    "집에서 자주 사용",\n    "티비 연결 및 플스 사용",\n    "보드게임 기능 재미",\n    "휴대용으로 편리",\n    "따뜻한 분위기",\n    "휴대용 플레이어",\n    "튼튼한 케이스",\n    "스마트폰 테더링 연결",\n    "기사님 서비스 만족",\n    "올려놓을 곳 필요",\n    "환불 불가",\n    "재고 부족",\n    "다양한 채널 및 게임 가능",\n    "활용도 높음",\n    "주변 부러움",\n    "룸앤티비 내구성 문제"\n  ]\n}',
#  '{\n  "제품 품질 및 만족도": ["훌륭한 제품", "고퀄리티", "소비자 만족", "재구매 의사", "귀한 상품", "기다리던 제품 도착", "공홈 구매 만족"],\n  "화면 및 음질": ["우수한 화면", "화면 만족", "선명한 화면", "우수한 스피커 음질", "영상 재생 만족"],\n  "캠핑 및 여행 활용": ["캠핑 장비로 적합", "캠핑 생활 업그레이드", "캠핑장에서 사용 계획", "캠핑용", "캠핑 사용", "여행 및 캠핑장에서 유용", "캠핑 및 여행에서 유용"],\n  "사용 편의성": ["편리한 리모컨 기능", "리모컨 필요", "편리한 음성지원", "리모컨 보관", "스크린 설치 불편함 대비 편리함"],\n  "다양한 활용도": ["회의용으로 사용", "노트북 및 스마트기기 연동", "다기능적 활용", "넷플릭스 및 유튜브 사용", "내장된 게임", "홈카페 활용", "드라마 시청", "유튜브 시청"],\n  "가격 및 가치": ["가격 유지", "가성비", "가격차이"],\n  "브랜드 및 제품 선호": ["LG 가전 선호", "엘지의 시도 응원"],\n  "공간 활용": ["좁은 공간에서 사용 가능", "안방에서 만족"],\n  "기타": ["평범함", "아내 선물", "직접 배송 신뢰", "광고 보고 구매", "유용한 장작불 화면", "제품 등록 문제", "LG Thin 어플 등록 가능", "감성 인테리어", "스탠바이미Go 추천"]\n}',
#  '{\n  "음향 및 스피커 관련": ["소리 작음", "개선된 스피커", "음악 만족", "깔끔한 스피커"],\n  "기대 및 기대감": ["추억 만들기 기대", "기대감", "기대되는 제품", "캠핑 사용 기대", "차박에서 사용 기대"],\n  "사용성 및 만족도": ["좋은 사용성", "높은 만족감", "게임 기능 만족", "아들이 좋아함", "아이들과 사용 만족", "가족 사용에 적합"],\n  "디자인 및 외형": ["세련된 디자인", "묵직한 무게", "단단한 제품 만듬새"],\n  "포장 및 배송": ["포장 만족", "직배송 만족", "안전한 직배송"],\n  "다양한 활용성": ["다양한 쓰임새", "집에서 사용", "차박 및 캠핑 활용도 높음", "집 및 외부에서 사용 가능", "외부 사용 적음", "여행 및 캠핑에서 사용"],\n  "기능 및 성능": ["유용한 기기", "스마트폰 연동", "넷플릭스 연결", "성능 괜찮음", "FHD 화질 좋음", "좋은 화면", "LG 디스플레이 인정", "깔끔한 모니터"],\n  "캠핑 및 여행 관련": ["캠핑 느낌", "캠핑에서 TV 필요성", "차박 및 캠핑 활용도 높음"],\n  "이벤트 및 혜택": ["리뷰 이벤트", "포토 이벤트 참여", "라이브 혜택"],\n  "구매 및 가격": ["국내 최저가 구매"],\n  "안정감 및 내구성": ["내구성 좋음", "안정감"],\n  "기타": ["개봉 예정", "좋은 행사", "음악으로 카페 분위기 연출"]\n}',
#  '{\n  "이동 및 사용성": ["차에서 활용 가능", "캠핑장에서 사용 기대", "집과 외부에서 사용성 좋음", "침대와 소파에서 사용", "닌텐도 연결 사용", "집에서 불멍 가능", "컴퓨터 모니터로 사용", "캠핑 및 가정에서 사용 만족", "집 및 야외 사용", "기숙사에서 사용", "어디서나 사용 가능"],\n  "미디어 및 엔터테인먼트": ["유튜브, 넷플릭스, 쿠팡플레이, 티빙 시청", "자기 전 사용", "아이들과 게임 가능", "집에서 영화보기 좋음"],\n  "제품 성능": ["빠른 반응속도", "좋은 터치감", "우수한 음질", "뛰어난 음질", "만족스러운 소리", "잘 작동"],\n  "제품 디자인 및 품질": ["디자인 좋음", "우수한 제품 퀄리티", "큰 사이즈"],\n  "배터리 및 전력": ["짧은 배터리 수명", "배터리 소모"],\n  "제품 만족도": ["스텐바이미 사용 만족", "스텐바이미고 사용 만족", "행사용 구입", "아이들과 잘 사용", "인싸 등극", "만족스러운 기능", "간단하게 볼만한 제품", "최고"],\n  "구매 및 추천": ["스탠바이미 Go 추천", "스탠드타입 구매 예정", "세컨티비로 적합"],\n  "배송 및 서비스": ["배송 과정 미흡", "원하는 날 배송", "고객 서비스 만족", "꼼꼼한 포장"],\n  "제품 문제점": ["화질 부족", "스크래치 문제", "커버 필요", "편리성 의문", "사전 안내 부족", "불쾌한 경험"]\n}',
#  '{\n  "제품 만족도": ["회사용도 기대", "동영상 시청 만족", "집에서 만족", "높은 활용성", "가격 대비 만족", "화질 만족", "터치감 만족", "공간 활용도 좋음", "작은 태블릿 화면보다 보기 좋음", "스탠바이미 GO의 매력", "업그레이드된 편리함", "제품 모으는 재미", "프로그램 만족", "싱글 사용 적합", "즐거움 증가", "감성 모드", "좋은 스피커", "이동성 만족", "사용 만족도", "추가 구매 의향"],\n  "기능 및 성능": ["피벗 기능", "다양한 영상비율 활용", "일반전원과 배터리전원 지원", "우렁찬 사운드", "빠른 반응", "지상파 기능 부족", "화질 열화", "화면 틸트 기능 불편", "모니터 손상 우려", "사진 로딩 불편", "유튜브 단축키 없음", "배터리 용량 확인 불편", "모니터 손상 위험", "충전 단자 위치 불편", "스크래치 우려", "알람 기능 없음"],\n  "이동 및 휴대성": ["여행용으로 유용", "캠핑 및 침실에서 사용", "캠핑 및 여행에 적합", "견고한 손잡이"],\n  "제품 디자인 및 구성": ["케이스 색상 만족", "접어서 보관 가능"],\n  "배터리 및 전원": ["배터리 수명", "4K 지원 희망"],\n  "배송 및 서비스": ["선물", "배송 연락", "제품 수령", "만족스러운 배송 절차"],\n  "기타": ["다른 용도", "실내용과 실외용의 차이"]\n}',
#  '{\n  "제품 성능 및 사용 만족": ["제품 개발과 판매 긍정적", "완벽한 기기", "영상 시청 만족", "우수한 음량", "견고함", "편리한 작동", "터치스크린 사용 편리", "좋은 터치", "충분한 화질", "충분한 음향", "FHD 화질", "엘지싱큐앱 리모컨 조절", "모니터 크기, 무게 만족", "사이즈 만족", "가족 사용 만족", "캠핑에 최적화", "캠핑장에서 인기", "차박에서 사용 만족", "가정에서 사용 만족", "캠핑장에서 TV 시청 눈치", "외부 브리핑용 사용", "외부 브리핑 사용", "집에서 TV 대체", "이동하면서 영상 및 티비 시청", "여행 시 사용"],\n  "배송 및 구매 경험": ["원하는 날에 배송", "시간에 맞는 배송", "9월 혜택 만족"],\n  "아이들과의 사용": ["아이들이 좋아함", "아이들과 게임"],\n  "캠핑 및 야외 활동": ["캠핑 추천", "불멍 용도"],\n  "리모컨 및 조작": ["리모콘 쟁탈전", "리모컨 분실 위험 없음"],\n  "화질 및 음향 문제": ["좋지 않은 화질", "화면 전송 끊김"],\n  "배터리 및 전력": ["내장 배터리", "작은 배터리 용량"],\n  "가격 및 가치": ["가격 대비 아쉬움"],\n  "기타": ["실내외 OTT 시청 가능", "다양한 OTT 플랫폼", "인터넷, 티비, 어플 호환성 문제", "아시아게임 응원", "LG전자의 시도", "BGM 재생", "대체로 만족", "각도 조절 용이"]\n}',
#  '{\n  "미디어 및 게임 시청": ["유튜브/넷플릭스 시청", "가족과 함께 시청", "닌텐도 스위치 게임", "다양한 게임", "재미있는 게임앱", "기본 게임 가능", "아이들에게 인기", "닌텐도 스위치 연결"],\n  "제품 활용성 및 휴대성": ["휴대성 있는 모니터", "캠핑에서 사용 가능", "차박에서 작은 화면 불편", "무선 휴대용 만족", "편리한 가방 구성", "캠핑 감성", "무게 수용 가능", "무거운 무게", "화면 크기 업그레이드 희망"],\n  "제품 품질 및 내구성": ["파손에 강함", "좋은 내구성", "안전한 제품 수령", "스크래치"],\n  "사용자 경험 및 만족도": ["행복함", "현재 만족", "구매 강추", "광고 영향으로 구매", "첫인상", "구매 결정", "엘지전자 제품 추천", "LG전자 품질 및 성능 신뢰"],\n  "기능 및 성능": ["리모컨 작동", "좋은 음성인식 기능", "터치 딜레이", "화질 개선 필요", "리얼한 소리", "구글 앱스토어 활용 희망"],\n  "사용 안내 및 서비스": ["사용 안내 아쉬움", "친절한 안내", "배송 안내 아쉬움", "전문 기사 직접 배송"],\n  "제품 구성 및 액세서리": ["선 길이", "케이스 필요", "배터리 충전 상태"],\n  "특별한 용도 및 상황": ["교육용 사용", "업무용 구매", "아이들 간의 평화", "사실적인 장작 영상", "내장된 부르마블 게임", "가족과 함께 시청", "차박에서 작은 화면 불편"],\n  "반품 및 불편 사항": ["반품 귀찮음"]\n}',
#  '{\n  "배터리 및 사용 시간": ["무선 사용 시간 짧음", "배터리 지속시간", "배터리 용량 부족"],\n  "브랜드 신뢰 및 만족": ["엘지 신뢰", "LG 제품에 대한 감탄", "엘지 제품 만족", "기대에 부응"],\n  "어플 및 기능 개선": ["어플 개선 필요", "유튜브 가능", "터치스크린 편리", "다양한 부가 기능"],\n  "사용 환경 및 활용성": ["캠핑 및 가정에서 활용도 높음", "영어 숙제에 유용", "영화 시청에 적합", "캠핑에서 아이 만족", "식사 중 TV 시청", "캠핑 및 외출 시 유용", "간단한 게임 가능", "많이 활용 가능", "야외 및 캠핑용 추천"],\n  "디자인 및 인테리어": ["새집 인테리어와 어울림", "만족스러운 디자인"],\n  "가족 및 개인 만족": ["가족의 만족", "신랑의 최애템"],\n  "구매 및 선물 추천": ["이사 선물로 적합", "판매 권장", "선물용 구매", "캠핑용 추가 구매"],\n  "배송 및 서비스": ["배송 일정 요청", "배송 확인 불가"],\n  "화질 및 사운드": ["눈 피로감 없음", "사운드 만족", "서라운드 모드", "화질 차이", "4K 미지원 아쉬움"],\n  "휴대성 및 무게": ["향상된 휴대성", "무겁지만 이동 편리", "무게감 아쉬움", "묵직하지만 들 수 있는 무게"],\n  "편의성 및 부가 기능": ["리모컨 사용", "편의성 만족", "블루투스 스피커 연결", "룸앤티비 업그레이드 느낌"],\n  "구매 방법 및 혜택": ["12개월 무이자 혜택", "라이브쇼핑 구매"],\n  "사무실 및 휴대용": ["사무실 휴대용"],\n  "성능 및 응답속도": ["빠른 응답속도"]\n}',
#  '{\n  "사용 환경": ["야외 사용 기대", "아늑한 영화관 느낌"],\n  "만족도": ["대대만족"]\n}']

# %%
len(themes)
# Out:
# 24

# %%
# 각 theme의 key를 추출하여 총 길이를 계산
total_keys_length = sum(len(json.loads(theme).keys()) for theme in themes)
total_keys_length
# Out:
# 206

# %%
from collections import defaultdict

# themes 리스트의 각 JSON 문자열을 dict 형태로 변환하여 병합하는 함수
def merge_themes(themes):
    merged_dict = defaultdict(list)  # 리스트를 기본값으로 갖는 defaultdict 생성

    for theme in themes:
        # JSON 문자열을 Python dict로 변환
        theme_dict = json.loads(theme)
        
        # 각 key와 value를 병합
        for key, values in theme_dict.items():
            for value in values:
                if value not in merged_dict[key]:  # 중복된 value가 없을 경우만 추가
                    merged_dict[key].append(value)
    
    return dict(merged_dict)  # defaultdict을 일반 dict로 변환하여 반환

# 예시: themes 리스트에서 병합된 결과를 출력
merged_themes = merge_themes(themes)

# %%
len(merged_themes.keys()) # batch 결과 206개 -> merge 결과 169개
# Out:
# 169

# %%
result
# Out:
#                                                raw_text       issue sentiment  \
# 0                                        조아용 조아용 조아용 ㅎㅎ       좋은 제품        긍정
# 1                                        너무 만족하며 사용중입니다          만족        긍정
# 2         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요    빠른 설치 배송        긍정
# 3         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요   설치 서비스 만족        긍정
# 4                          여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요     여자친구 만족        긍정
# ...                                                 ...         ...       ...
# 2468  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...    야외 사용 기대        긍정
# 2469  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...        대대만족        긍정
# 2470  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...  아늑한 영화관 느낌        긍정
# 2471  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...       이동 편리        긍정
# 2472  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...     캠핑에서 유용        긍정
#
#      sentiment_all
# 0               긍정
# 1               긍정
# 2               긍정
# 3               긍정
# 4               긍정
# ...            ...
# 2468            긍정
# 2469            긍정
# 2470            긍정
# 2471            긍정
# 2472            긍정
#
# [2473 rows x 4 columns]

# %%
result_test = result.copy()

# %%
# 'theme' 컬럼을 생성하는 함수
def find_theme(issue):
    for theme, issues in merged_themes.items():
        if issue in issues:
            return theme
    return '기타'  # 해당하는 theme이 없을 경우 '기타'로 표시

# 'theme' 컬럼을 생성
result_test['theme'] = result_test['issue'].apply(find_theme)
result_test
# Out:
#                                                raw_text       issue sentiment  \
# 0                                        조아용 조아용 조아용 ㅎㅎ       좋은 제품        긍정
# 1                                        너무 만족하며 사용중입니다          만족        긍정
# 2         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요    빠른 설치 배송        긍정
# 3         4일이내 설치배송연락받았고 원하는날 안착완료^^제품 설치 서비스 모두모두 만족이요   설치 서비스 만족        긍정
# 4                          여자친구가 너무 만족합니다. 생일때 사줄걸 그랬어요     여자친구 만족        긍정
# ...                                                 ...         ...       ...
# 2468  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...    야외 사용 기대        긍정
# 2469  일단 디자인이 너무 이쁘고 기능도 많아 왜 이제 샀나 싶은 제품 이에요~ 야외도 한...        대대만족        긍정
# 2470  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...  아늑한 영화관 느낌        긍정
# 2471  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...       이동 편리        긍정
# 2472  침대 앞에 두니 아늑한 영화관이 생겼네요-!여기저기 옮겨 다니며 보기 편해요캠핑 갈...     캠핑에서 유용        긍정
#
#      sentiment_all        theme
# 0               긍정   제품 품질 및 성능
# 1               긍정      사용자 만족도
# 2               긍정  설치 및 배송 서비스
# 3               긍정  설치 및 배송 서비스
# 4               긍정      사용자 만족도
# ...            ...          ...
# 2468            긍정        사용 환경
# 2469            긍정          만족도
# 2470            긍정        사용 환경
# 2471            긍정    편리성 및 사용성
# 2472            긍정     캠핑 및 휴대성
#
# [2473 rows x 5 columns]

# %%
result_test.to_pickle('result/제공_네이버쇼핑리뷰_batch50_감성테마.pkl')

# %%
result_test.to_excel('result/제공_네이버쇼핑리뷰_감성테마_batch50_test1.xlsx', index=False)

# %% [markdown]
# ### batch100

# %%
# 유니크한 이슈들을 GPT API로 분류
themes = []
batch_size = 100  # 한번에 너무 많은 데이터를 보내지 않기 위해 배치 처리
for i in range(0, len(unique_issues), batch_size):
    batch_issues = unique_issues[i:i+batch_size]
    themes.append(classify_issues(', '.join(batch_issues)))

# 배치 결과를 합쳐서 하나의 테마 리스트로 변환
theme_list = [theme.strip() for theme in ', '.join(themes).split(',')]
